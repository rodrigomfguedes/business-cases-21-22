# %% [markdown]
# <!-- <div>
#     <img src="attachment:image.png" align="right" width="150">
# </div> -->
#
# # <font color='#5D6D7E '> <center >Forecasting - LINK</center>
#
# ### Master Degree Program in Data Science and Advanced Analytics
#
# ### <font color='#5D6D7E '> Business Cases with Data Science Project:
# > #### Group AA
#
# ### <font color='#5D6D7E '> Done by:
# > #### - Beatriz Martins Selidónio Gomes, m20210545
# > #### - Catarina Inês Lopes Garcez, m20210547
# > #### - Diogo André Domingues Pires, m20201076
# > #### - Rodrigo Faísca Guedes, m20210587

# %% [markdown]
# ---

# %% [markdown]
# <div>
#
# # Table of Content<a class="anchor"><a id='toc'></a>
#
# ### <font color='#5D6D7E '> Import and Data Integration
# - [<font color='#000000'>Import the needed Libraries</font>](#third-bullet)<br>
#
# ### <font color='#5D6D7E '> Data Exploration and Understanding
# - [<font color='#000000'>Initial Analysis (EDA - Exploratory Data Analysis)</font>](#fifth-bullet)<br>
# - [<font color='#000000'>Variables Distribution</font>](#seventh-bullet)<br>
#
# ### <font color='#5D6D7E '> Data Preparation
# - [<font color='#000000'>Data Transformation</font>](#eighth-bullet)<br>
#
# ### <font color='#5D6D7E '> Modelling
# - [<font color='#000000'>Building LSTM Model</font>](#twentysecond-bullet)<br>
# - [<font color='#000000'>Get Best Parameters for LSTM</font>](#twentythird-bullet)<br>
# - [<font color='#000000'>Run the LSTM Model and Get Predictions</font>](#twentyfourth-bullet)<br>
# - [<font color='#000000'>Recursive Predictions</font>](#twentysixth-bullet)<br>
#
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Import and Data Integration
#
#
# ## <font color='#5D6D7E '>Import the needed Libraries</font> <a class="anchor" id="third-bullet"></a>
#   [Back to TOC](#toc)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Exploration and Understanding
#
# ## <font color='#5D6D7E'>Initial Analysis (EDA - Exploratory Data Analysis) </font> <a class="anchor" id="fifth-bullet"></a>
#   [Back to TOC](#toc)

# %%
df = pd.read_csv('../data/data_aux/df_LINK.csv')
df
# Out:
#             Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  \
# 0     2017-04-26                NaN             NaN            NaN
# 1     2017-04-27                NaN             NaN            NaN
# 2     2017-04-28                NaN             NaN            NaN
# 3     2017-04-29                NaN             NaN            NaN
# 4     2017-04-30                NaN             NaN            NaN
# ...          ...                ...             ...            ...
# 1821  2022-04-21          13.588746       13.588746      14.346668
# 1822  2022-04-22          13.609354       13.609354      13.852832
# 1823  2022-04-23          13.343726       13.343726      13.643617
# 1824  2022-04-24          13.287423       13.287423      13.608301
# 1825  2022-04-25          13.458693       13.458693      13.487024
#
#       LINK-USD_LOW  LINK-USD_OPEN  LINK-USD_VOLUME
# 0              NaN            NaN              NaN
# 1              NaN            NaN              NaN
# 2              NaN            NaN              NaN
# 3              NaN            NaN              NaN
# 4              NaN            NaN              NaN
# ...            ...            ...              ...
# 1821     13.472289      14.022598      503314643.0
# 1822     13.506432      13.587431      464995123.0
# 1823     13.328945      13.609134      322384215.0
# 1824     13.275181      13.341961      299368814.0
# 1825     12.576232      13.287835      506454272.0
#
# [1826 rows x 7 columns]

# %% [markdown]
# ### Data Types

# %%
# Get to know the number of instances and Features, the DataTypes and if there are missing values in each Feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1826 non-null   object
#  1   LINK-USD_ADJCLOSE  1629 non-null   float64
#  2   LINK-USD_CLOSE     1629 non-null   float64
#  3   LINK-USD_HIGH      1629 non-null   float64
#  4   LINK-USD_LOW       1629 non-null   float64
#  5   LINK-USD_OPEN      1629 non-null   float64
#  6   LINK-USD_VOLUME    1629 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 100.0+ KB

# %% [markdown]
# ### Missing Values

# %%
# Count the number of missing values for each Feature
df.isna().sum().to_frame().rename(columns={0: 'Count Missing Values'})
# Out:
#                    Count Missing Values
# Date                                  0
# LINK-USD_ADJCLOSE                   197
# LINK-USD_CLOSE                      197
# LINK-USD_HIGH                       197
# LINK-USD_LOW                        197
# LINK-USD_OPEN                       197
# LINK-USD_VOLUME                     197

# %% [markdown]
# ### Descriptive Statistics

# %%
# Descriptive Statistics Table
df.describe().T
# Out:
#                     count          mean           std            min  \
# LINK-USD_ADJCLOSE  1629.0  9.278496e+00  1.109668e+01       0.145255
# LINK-USD_CLOSE     1629.0  9.278496e+00  1.109668e+01       0.145255
# LINK-USD_HIGH      1629.0  9.718100e+00  1.165490e+01       0.166283
# LINK-USD_LOW       1629.0  8.782255e+00  1.045464e+01       0.137963
# LINK-USD_OPEN      1629.0  9.271041e+00  1.109892e+01       0.147360
# LINK-USD_VOLUME    1629.0  7.841433e+08  4.314155e+09  398773.000000
#
#                             25%           50%           75%           max
# LINK-USD_ADJCLOSE  4.924770e-01  2.787380e+00  1.609130e+01  5.219870e+01
# LINK-USD_CLOSE     4.924770e-01  2.787380e+00  1.609130e+01  5.219870e+01
# LINK-USD_HIGH      5.158940e-01  2.874556e+00  1.674419e+01  5.287609e+01
# LINK-USD_LOW       4.716800e-01  2.690064e+00  1.528594e+01  4.672922e+01
# LINK-USD_OPEN      4.922220e-01  2.782405e+00  1.609040e+01  5.224769e+01
# LINK-USD_VOLUME    8.182734e+06  2.240961e+08  1.073605e+09  1.705493e+11

# %%
# settings to display all columns
pd.set_option("display.max_columns", None)

# display the dataframe head
df.sample(n=10)
# Out:
#             Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  \
# 1254  2020-10-01           9.649905        9.649905      10.373128
# 70    2017-07-05                NaN             NaN            NaN
# 1742  2022-02-01          17.024292       17.024292      17.787558
# 0     2017-04-26                NaN             NaN            NaN
# 1370  2021-01-25          23.540121       23.540121      25.654894
# 893   2019-10-06           2.188103        2.188103       2.268636
# 105   2017-08-09                NaN             NaN            NaN
# 1744  2022-02-03          16.178110       16.178110      16.243290
# 1577  2021-08-20          28.701841       28.701841      28.979713
# 1748  2022-02-07          18.876795       18.876795      19.323885
#
#       LINK-USD_LOW  LINK-USD_OPEN  LINK-USD_VOLUME
# 1254      9.453802       9.871626     1.426296e+09
# 70             NaN            NaN              NaN
# 1742     16.922941      17.238232     8.672248e+08
# 0              NaN            NaN              NaN
# 1370     22.738539      24.699432     3.740983e+09
# 893       1.963500       1.965752     1.263566e+08
# 105            NaN            NaN              NaN
# 1744     15.368828      15.812665     7.034998e+08
# 1577     26.707174      27.060467     1.751490e+09
# 1748     17.746798      18.042583     9.659710e+08

# %%
#CHECK ROWS THAT HAVE ANY MISSING VALUE IN ONE OF THE COLUMNS
is_NaN = df.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = df[row_has_NaN]
rows_with_NaN
# Out:
#            Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  \
# 0    2017-04-26                NaN             NaN            NaN
# 1    2017-04-27                NaN             NaN            NaN
# 2    2017-04-28                NaN             NaN            NaN
# 3    2017-04-29                NaN             NaN            NaN
# 4    2017-04-30                NaN             NaN            NaN
# ..          ...                ...             ...            ...
# 192  2017-11-04                NaN             NaN            NaN
# 193  2017-11-05                NaN             NaN            NaN
# 194  2017-11-06                NaN             NaN            NaN
# 195  2017-11-07                NaN             NaN            NaN
# 196  2017-11-08                NaN             NaN            NaN
#
#      LINK-USD_LOW  LINK-USD_OPEN  LINK-USD_VOLUME
# 0             NaN            NaN              NaN
# 1             NaN            NaN              NaN
# 2             NaN            NaN              NaN
# 3             NaN            NaN              NaN
# 4             NaN            NaN              NaN
# ..            ...            ...              ...
# 192           NaN            NaN              NaN
# 193           NaN            NaN              NaN
# 194           NaN            NaN              NaN
# 195           NaN            NaN              NaN
# 196           NaN            NaN              NaN
#
# [197 rows x 7 columns]

# %%
#FILTER OUT ROWS THAT ARE MISSING INFORMATION
df = df[~row_has_NaN]
df.reset_index(inplace=True, drop=True)
df
# Out:
#             Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  \
# 0     2017-11-09           0.223969        0.223969       0.248233
# 1     2017-11-10           0.187602        0.187602       0.231280
# 2     2017-11-11           0.179770        0.179770       0.197687
# 3     2017-11-12           0.170898        0.170898       0.198376
# 4     2017-11-13           0.183071        0.183071       0.205014
# ...          ...                ...             ...            ...
# 1624  2022-04-21          13.588746       13.588746      14.346668
# 1625  2022-04-22          13.609354       13.609354      13.852832
# 1626  2022-04-23          13.343726       13.343726      13.643617
# 1627  2022-04-24          13.287423       13.287423      13.608301
# 1628  2022-04-25          13.458693       13.458693      13.487024
#
#       LINK-USD_LOW  LINK-USD_OPEN  LINK-USD_VOLUME
# 0         0.195411       0.216713        3347920.0
# 1         0.180161       0.224700        2125460.0
# 2         0.166026       0.186398        2238980.0
# 3         0.145948       0.179667        5455200.0
# 4         0.168743       0.169117        2992650.0
# ...            ...            ...              ...
# 1624     13.472289      14.022598      503314643.0
# 1625     13.506432      13.587431      464995123.0
# 1626     13.328945      13.609134      322384215.0
# 1627     13.275181      13.341961      299368814.0
# 1628     12.576232      13.287835      506454272.0
#
# [1629 rows x 7 columns]

# %% [markdown]
# # Data Preparation
#
#
# ## <font color='#5D6D7E'>Data Transformation</font> <a class="anchor" id="eighth-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
#  __`Duplicates`__

# %%
# Checking if exist duplicated observations
print(f'\033[1m' + "Number of duplicates: " + '\033[0m', df.duplicated().sum())
# Out:
# Number of duplicates:  0

# %% [markdown]
#  __`Convert Date to correct format`__

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df
# Out:
#            Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  \
# 0    2017-11-09           0.223969        0.223969       0.248233
# 1    2017-11-10           0.187602        0.187602       0.231280
# 2    2017-11-11           0.179770        0.179770       0.197687
# 3    2017-11-12           0.170898        0.170898       0.198376
# 4    2017-11-13           0.183071        0.183071       0.205014
# ...         ...                ...             ...            ...
# 1624 2022-04-21          13.588746       13.588746      14.346668
# 1625 2022-04-22          13.609354       13.609354      13.852832
# 1626 2022-04-23          13.343726       13.343726      13.643617
# 1627 2022-04-24          13.287423       13.287423      13.608301
# 1628 2022-04-25          13.458693       13.458693      13.487024
#
#       LINK-USD_LOW  LINK-USD_OPEN  LINK-USD_VOLUME
# 0         0.195411       0.216713        3347920.0
# 1         0.180161       0.224700        2125460.0
# 2         0.166026       0.186398        2238980.0
# 3         0.145948       0.179667        5455200.0
# 4         0.168743       0.169117        2992650.0
# ...            ...            ...              ...
# 1624     13.472289      14.022598      503314643.0
# 1625     13.506432      13.587431      464995123.0
# 1626     13.328945      13.609134      322384215.0
# 1627     13.275181      13.341961      299368814.0
# 1628     12.576232      13.287835      506454272.0
#
# [1629 rows x 7 columns]

# %% [markdown]
#  __`Get percentual difference between open and close values and low and high values`__

# %%
df['pctDiff_CloseOpen'] = abs((df[df.columns[2]]-df[df.columns[5]])/df[df.columns[2]])*100
df['pctDiff_HighLow'] = abs((df[df.columns[3]]-df[df.columns[4]])/df[df.columns[4]])*100
df.head()
# Out:
#         Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  LINK-USD_LOW  \
# 0 2017-11-09           0.223969        0.223969       0.248233      0.195411
# 1 2017-11-10           0.187602        0.187602       0.231280      0.180161
# 2 2017-11-11           0.179770        0.179770       0.197687      0.166026
# 3 2017-11-12           0.170898        0.170898       0.198376      0.145948
# 4 2017-11-13           0.183071        0.183071       0.205014      0.168743
#
#    LINK-USD_OPEN  LINK-USD_VOLUME  pctDiff_CloseOpen  pctDiff_HighLow
# 0       0.216713        3347920.0           3.239735        27.031237
# 1       0.224700        2125460.0          19.774846        28.374065
# 2       0.186398        2238980.0           3.686937        19.069907
# 3       0.179667        5455200.0           5.131125        35.922390
# 4       0.169117        2992650.0           7.622179        21.494821

# %%
def plot_coinValue(df):
    
    #Get coin name
    coin_name = df.columns[2].split('-')[0]
    
    #Get date and coin value
    x = df['Date']
    y = df[df.columns[2]] # ADA-USD_CLOSE
    
    #Get the volume of trades
    v = df[df.columns[-3]]/1e9
    
    #Get percentual diferences
    y2 = df[df.columns[-1]] # pctDiff_HighLow
    y1= df[df.columns[-2]]  # pctDiff_CloseOpen
    
    fig, axs = plt.subplots(3, 1, figsize=(12,14))
    
    axs[0].plot(x, y)
    axs[2].plot(x, v)
    
    # plotting the line 1 points 
    axs[1].plot(x, y1, label = "Close/Open")

    # plotting the line 2 points 
    axs[1].plot(x, y2, label = "High/Low")
    axs[1].legend()
    
    axs[0].title.set_text('Time Evolution of '+ coin_name)
    axs[0].set(xlabel="", ylabel="Close Value in USD$")
    
    axs[2].title.set_text('Volume of trades of '+ coin_name)
    axs[2].set(xlabel="", ylabel="Total number of trades in billions")
    
    
    axs[1].title.set_text('Daily Market percentual differences of '+ coin_name)
    axs[1].set(xlabel="", ylabel="Percentage (%)")
    
    plt.savefig('../analysis/'+coin_name +'_stats'+'.png')
    
    return coin_name

# %%
coin_name = plot_coinValue(df)

# %%
#FILTER DATASET
df = df.loc[df['Date']>= '2021-11-01']
df
# Out:
#            Date  LINK-USD_ADJCLOSE  LINK-USD_CLOSE  LINK-USD_HIGH  \
# 1453 2021-11-01          31.565237       31.565237      31.871412
# 1454 2021-11-02          32.265533       32.265533      32.496296
# 1455 2021-11-03          31.990866       31.990866      32.791611
# 1456 2021-11-04          31.020929       31.020929      32.101528
# 1457 2021-11-05          32.917904       32.917904      33.696304
# ...         ...                ...             ...            ...
# 1624 2022-04-21          13.588746       13.588746      14.346668
# 1625 2022-04-22          13.609354       13.609354      13.852832
# 1626 2022-04-23          13.343726       13.343726      13.643617
# 1627 2022-04-24          13.287423       13.287423      13.608301
# 1628 2022-04-25          13.458693       13.458693      13.487024
#
#       LINK-USD_LOW  LINK-USD_OPEN  LINK-USD_VOLUME  pctDiff_CloseOpen  \
# 1453     29.208277      30.002562     1.143381e+09           4.950622
# 1454     31.043903      31.685040     1.026698e+09           1.799115
# 1455     30.673016      32.265514     1.115162e+09           0.858522
# 1456     30.289692      31.971289     8.968978e+08           3.063607
# 1457     30.725060      31.027643     1.516149e+09           5.742348
# ...            ...            ...              ...                ...
# 1624     13.472289      14.022598     5.033146e+08           3.192732
# 1625     13.506432      13.587431     4.649951e+08           0.161088
# 1626     13.328945      13.609134     3.223842e+08           1.989006
# 1627     13.275181      13.341961     2.993688e+08           0.410447
# 1628     12.576232      13.287835     5.064543e+08           1.269495
#
#       pctDiff_HighLow
# 1453         9.117743
# 1454         4.678511
# 1455         6.907032
# 1456         5.981693
# 1457         9.670428
# ...               ...
# 1624         6.490205
# 1625         2.564706
# 1626         2.360813
# 1627         2.509347
# 1628         7.242172
#
# [176 rows x 9 columns]

# %% [markdown]
# # Modelling
#
#
# ## <font color='#5D6D7E'>Building LSTM Model</font> <a class="anchor" id="twentysecond-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
# ## Strategy
#
# Create a DF (windowed_df) where the middle columns will correspond to the close values of X days before the target date and the final column will correspond to the close value of the target date. Use these values for prediction and play with the value of X

# %%
def get_windowed_df(X, df):
    start_Date = df['Date'] + pd.Timedelta(days=X)
    
    perm = np.zeros((1,X+1))
    
    #Get labels for DataFrame
    j=1
    labels=[]
    
    while j <= X:
        label = 'closeValue_' + str(j) + 'daysBefore'
        labels.append(label)
        
        j+=1
 
    labels.append('closeValue')
    
    for i in range(X,df.shape[0]):
        temp = np.zeros((1,X+1))
        
        #Date for i-th day
        #temp[0,0] = df.iloc[i]['Date']
        
        #Close values for k days before
        for k in range(X):           
            temp[0,k] = df.iloc[i-k-1,2]
            
        #Close value for i-th date
        temp[0,-1] = df.iloc[i,2]
        

        #Add values to the permanent frame
        perm = np.vstack((perm,temp))
        
        #Get the array in dataframe form
        windowed_df = pd.DataFrame(perm[1:,:], columns = labels)
        
    return windowed_df

# %%
#Get the dataframe and append the dates
windowed_df = get_windowed_df(4, df)
windowed_df['Date'] = df.iloc[4:]['Date'].reset_index(drop=True)
windowed_df
# Out:
#      closeValue_1daysBefore  closeValue_2daysBefore  closeValue_3daysBefore  \
# 0                 31.020929               31.990866               32.265533
# 1                 32.917904               31.020929               31.990866
# 2                 32.083439               32.917904               31.020929
# 3                 32.349564               32.083439               32.917904
# 4                 34.477592               32.349564               32.083439
# ..                      ...                     ...                     ...
# 167               14.024039               14.258342               14.037702
# 168               13.588746               14.024039               14.258342
# 169               13.609354               13.588746               14.024039
# 170               13.343726               13.609354               13.588746
# 171               13.287423               13.343726               13.609354
#
#      closeValue_4daysBefore  closeValue       Date
# 0                 31.565237   32.917904 2021-11-05
# 1                 32.265533   32.083439 2021-11-06
# 2                 31.990866   32.349564 2021-11-07
# 3                 31.020929   34.477592 2021-11-08
# 4                 32.917904   33.859272 2021-11-09
# ..                      ...         ...        ...
# 167               13.764988   13.588746 2022-04-21
# 168               14.037702   13.609354 2022-04-22
# 169               14.258342   13.343726 2022-04-23
# 170               14.024039   13.287423 2022-04-24
# 171               13.588746   13.458693 2022-04-25
#
# [172 rows x 6 columns]

# %%
#Get the X,y and dates into a numpy array to apply on a model

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    dates = df_as_np[:, -1]

    middle_matrix = df_as_np[:, 0:-2]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    Y = df_as_np[:, -2]

    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((172,), (172, 4, 1), (172,))

# %%
#Partition for train, validation and test

q_80 = int(len(dates) * .85)
q_90 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

fig,axs = plt.subplots(1, 1, figsize=(12,5))

#Plot the partitions
axs.plot(dates_train, y_train)
axs.plot(dates_val, y_val)
axs.plot(dates_test, y_test)

axs.legend(['Train', 'Validation', 'Test'])

fig.savefig('../analysis/'+coin_name +'_partition'+'.png')

# %% [markdown]
# ## <font color='#5D6D7E'>Get Best Parameters for LSTM</font> <a class="anchor" id="twentythird-bullet"></a>
#   [Back to TOC](#toc)

# %%
#!pip install tensorflow

# %%
#import os
#os.environ['PYTHONHASHSEED']= '0'
#import numpy as np
#np.random.seed(1)
#import random as rn
#rn.seed(1)
#import tensorflow as tf
#tf.random.set_seed(1)
#
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.optimizers import Adam
#from tensorflow.keras import layers
#from sklearn.metrics import mean_squared_error
#
## Function to create LSTM model and compute the MSE value for the given parameters
#def check_model(X_train, y_train, X_val, y_val, X_test, y_test, learning_rate,epoch,batch):
#    
#    # create model
#    model = Sequential([layers.Input((4, 1)),
#                        layers.LSTM(64),
#                        layers.Dense(32, activation='relu'),
#                        layers.Dense(32, activation='relu'),
#                        layers.Dense(1)])
#    # Compile model
#    model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate), metrics=['mean_absolute_error'])
#    
#    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epoch, shuffle=False, batch_size=batch, verbose=2)
#    
#    test_predictions = model.predict(X_test).flatten()
#    
#    LSTM_mse = mean_squared_error(y_test, test_predictions)
#    
#    return LSTM_mse
#
##Function that iterates the different parameters and gets the ones corresponding to the lowest MSE score.
#def search_parameters(batch_size, epochs, learn_rate, X_train, y_train, X_val, y_val, X_test, y_test):
#    
#    best_score = float('inf')
#    
#    for b in batch_size:
#        for e in epochs:
#            for l in learn_rate:
#                print('Batch Size: ' + str(b))
#                print('Number of Epochs: ' + str(e))
#                print('Value of Learning Rate: ' + str(l))
#                try:
#                    mse = check_model(X_train, y_train, X_val, y_val, X_test, y_test,l,e,b)
#                    print('MSE=%.3f' % (mse))
#                    if mse < best_score:
#                        best_score = mse
#                        top_params = [b, e, l]
#                except:
#                    continue
#                    
#    print('Best MSE=%.3f' % (best_score))
#    print('Optimal Batch Size: ' + str(top_params[0]))
#    print('Optimal Number of Epochs: ' + str(top_params[1]))
#    print('Optimal Value of Learning Rate: ' + str(top_params[2]))
#                        
#
## define parameters
#batch_size = [10, 100, 1000]
#epochs = [50, 100]
#learn_rate = np.linspace(0.001,0.1, num=10)
#
#warnings.filterwarnings("ignore")
#search_parameters(batch_size, epochs, learn_rate, X_train, y_train, X_val, y_val, X_test, y_test)

# %% [markdown]
# ## <font color='#5D6D7E'>Run the LSTM Model and Get Predictions</font> <a class="anchor" id="twentyfourth-bullet"></a>
#   [Back to TOC](#toc)

# %%
#BEST SOLUTION OF THE MODEL

# MSE=0.201
# Batch Size: 10
# Number of Epochs: 50
# Value of Learning Rate: 0.001

from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error

model = Sequential([layers.Input((4, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50, shuffle=False, batch_size=10, verbose=2)
# Out:
# Epoch 1/50
# 15/15 - 1s - loss: 421.7359 - mean_absolute_error: 19.5956 - val_loss: 201.3502 - val_mean_absolute_error: 14.1152 - 1s/epoch - 98ms/step
# Epoch 2/50
# 15/15 - 0s - loss: 362.7286 - mean_absolute_error: 17.9146 - val_loss: 136.6856 - val_mean_absolute_error: 11.5960 - 47ms/epoch - 3ms/step
# Epoch 3/50
# 15/15 - 0s - loss: 262.0267 - mean_absolute_error: 14.3694 - val_loss: 39.3510 - val_mean_absolute_error: 6.0872 - 42ms/epoch - 3ms/step
# Epoch 4/50
# 15/15 - 0s - loss: 131.3840 - mean_absolute_error: 8.5473 - val_loss: 5.0414 - val_mean_absolute_error: 1.8414 - 44ms/epoch - 3ms/step
# Epoch 5/50
# 15/15 - 0s - loss: 60.5962 - mean_absolute_error: 6.3614 - val_loss: 34.2855 - val_mean_absolute_error: 5.6701 - 43ms/epoch - 3ms/step
# Epoch 6/50
# 15/15 - 0s - loss: 38.7097 - mean_absolute_error: 5.3060 - val_loss: 26.6910 - val_mean_absolute_error: 4.9635 - 44ms/epoch - 3ms/step
# Epoch 7/50
# 15/15 - 0s - loss: 34.4598 - mean_absolute_error: 4.8714 - val_loss: 18.8864 - val_mean_absolute_error: 4.1108 - 44ms/epoch - 3ms/step
# Epoch 8/50
# 15/15 - 0s - loss: 34.9619 - mean_absolute_error: 4.8167 - val_loss: 17.0245 - val_mean_absolute_error: 3.8861 - 44ms/epoch - 3ms/step
# Epoch 9/50
# 15/15 - 0s - loss: 34.1848 - mean_absolute_error: 4.7634 - val_loss: 16.8020 - val_mean_absolute_error: 3.8721 - 45ms/epoch - 3ms/step
# Epoch 10/50
# 15/15 - 0s - loss: 30.5519 - mean_absolute_error: 4.4491 - val_loss: 10.1557 - val_mean_absolute_error: 2.9331 - 43ms/epoch - 3ms/step
# Epoch 11/50
# 15/15 - 0s - loss: 27.0673 - mean_absolute_error: 4.0775 - val_loss: 6.8860 - val_mean_absolute_error: 2.3386 - 45ms/epoch - 3ms/step
# Epoch 12/50
# 15/15 - 0s - loss: 22.6727 - mean_absolute_error: 3.6773 - val_loss: 3.8421 - val_mean_absolute_error: 1.6929 - 46ms/epoch - 3ms/step
# Epoch 13/50
# 15/15 - 0s - loss: 16.3491 - mean_absolute_error: 2.9339 - val_loss: 1.4373 - val_mean_absolute_error: 1.0454 - 45ms/epoch - 3ms/step
# Epoch 14/50
# 15/15 - 0s - loss: 11.3840 - mean_absolute_error: 2.3992 - val_loss: 0.9536 - val_mean_absolute_error: 0.8364 - 45ms/epoch - 3ms/step
# Epoch 15/50
# 15/15 - 0s - loss: 7.8555 - mean_absolute_error: 1.9898 - val_loss: 0.9331 - val_mean_absolute_error: 0.8290 - 44ms/epoch - 3ms/step
# Epoch 16/50
# 15/15 - 0s - loss: 5.9913 - mean_absolute_error: 1.7788 - val_loss: 0.8550 - val_mean_absolute_error: 0.8055 - 44ms/epoch - 3ms/step
# Epoch 17/50
# 15/15 - 0s - loss: 5.3180 - mean_absolute_error: 1.7008 - val_loss: 0.8493 - val_mean_absolute_error: 0.7942 - 44ms/epoch - 3ms/step
# Epoch 18/50
# 15/15 - 0s - loss: 4.8601 - mean_absolute_error: 1.6757 - val_loss: 0.8680 - val_mean_absolute_error: 0.7982 - 44ms/epoch - 3ms/step
# Epoch 19/50
# 15/15 - 0s - loss: 4.1197 - mean_absolute_error: 1.5843 - val_loss: 0.8869 - val_mean_absolute_error: 0.7938 - 45ms/epoch - 3ms/step
# Epoch 20/50
# 15/15 - 0s - loss: 3.8025 - mean_absolute_error: 1.5351 - val_loss: 0.8199 - val_mean_absolute_error: 0.7787 - 44ms/epoch - 3ms/step
# Epoch 21/50
# 15/15 - 0s - loss: 3.7516 - mean_absolute_error: 1.5309 - val_loss: 0.8149 - val_mean_absolute_error: 0.7741 - 45ms/epoch - 3ms/step
# Epoch 22/50
# 15/15 - 0s - loss: 3.4703 - mean_absolute_error: 1.5008 - val_loss: 0.8460 - val_mean_absolute_error: 0.7725 - 45ms/epoch - 3ms/step
# Epoch 23/50
# 15/15 - 0s - loss: 3.2797 - mean_absolute_error: 1.4643 - val_loss: 0.8159 - val_mean_absolute_error: 0.7641 - 45ms/epoch - 3ms/step
# Epoch 24/50
# 15/15 - 0s - loss: 3.2413 - mean_absolute_error: 1.4539 - val_loss: 0.7762 - val_mean_absolute_error: 0.7551 - 45ms/epoch - 3ms/step
# Epoch 25/50
# 15/15 - 0s - loss: 3.1314 - mean_absolute_error: 1.4366 - val_loss: 0.8059 - val_mean_absolute_error: 0.7535 - 45ms/epoch - 3ms/step
# Epoch 26/50
# 15/15 - 0s - loss: 3.0053 - mean_absolute_error: 1.4078 - val_loss: 0.7941 - val_mean_absolute_error: 0.7475 - 46ms/epoch - 3ms/step
# Epoch 27/50
# 15/15 - 0s - loss: 2.9573 - mean_absolute_error: 1.3955 - val_loss: 0.7512 - val_mean_absolute_error: 0.7379 - 47ms/epoch - 3ms/step
# Epoch 28/50
# 15/15 - 0s - loss: 2.9018 - mean_absolute_error: 1.3852 - val_loss: 0.7577 - val_mean_absolute_error: 0.7324 - 49ms/epoch - 3ms/step
# Epoch 29/50
# 15/15 - 0s - loss: 2.8208 - mean_absolute_error: 1.3658 - val_loss: 0.7540 - val_mean_absolute_error: 0.7264 - 46ms/epoch - 3ms/step
# Epoch 30/50
# 15/15 - 0s - loss: 2.7719 - mean_absolute_error: 1.3532 - val_loss: 0.7202 - val_mean_absolute_error: 0.7168 - 44ms/epoch - 3ms/step
# Epoch 31/50
# 15/15 - 0s - loss: 2.7315 - mean_absolute_error: 1.3433 - val_loss: 0.7101 - val_mean_absolute_error: 0.7087 - 44ms/epoch - 3ms/step
# Epoch 32/50
# 15/15 - 0s - loss: 2.6758 - mean_absolute_error: 1.3288 - val_loss: 0.7045 - val_mean_absolute_error: 0.7014 - 45ms/epoch - 3ms/step
# Epoch 33/50
# 15/15 - 0s - loss: 2.6321 - mean_absolute_error: 1.3168 - val_loss: 0.6815 - val_mean_absolute_error: 0.6919 - 46ms/epoch - 3ms/step
# Epoch 34/50
# 15/15 - 0s - loss: 2.5914 - mean_absolute_error: 1.3069 - val_loss: 0.6650 - val_mean_absolute_error: 0.6824 - 43ms/epoch - 3ms/step
# Epoch 35/50
# 15/15 - 0s - loss: 2.5495 - mean_absolute_error: 1.2956 - val_loss: 0.6502 - val_mean_absolute_error: 0.6730 - 44ms/epoch - 3ms/step
# Epoch 36/50
# 15/15 - 0s - loss: 2.5102 - mean_absolute_error: 1.2857 - val_loss: 0.6316 - val_mean_absolute_error: 0.6626 - 45ms/epoch - 3ms/step
# Epoch 37/50
# 15/15 - 0s - loss: 2.4729 - mean_absolute_error: 1.2761 - val_loss: 0.6141 - val_mean_absolute_error: 0.6521 - 45ms/epoch - 3ms/step
# Epoch 38/50
# 15/15 - 0s - loss: 2.4375 - mean_absolute_error: 1.2670 - val_loss: 0.5975 - val_mean_absolute_error: 0.6414 - 46ms/epoch - 3ms/step
# Epoch 39/50
# 15/15 - 0s - loss: 2.3988 - mean_absolute_error: 1.2568 - val_loss: 0.5813 - val_mean_absolute_error: 0.6307 - 45ms/epoch - 3ms/step
# Epoch 40/50
# 15/15 - 0s - loss: 2.3632 - mean_absolute_error: 1.2471 - val_loss: 0.5636 - val_mean_absolute_error: 0.6200 - 40ms/epoch - 3ms/step
# Epoch 41/50
# 15/15 - 0s - loss: 2.3321 - mean_absolute_error: 1.2393 - val_loss: 0.5464 - val_mean_absolute_error: 0.6085 - 40ms/epoch - 3ms/step
# Epoch 42/50
# 15/15 - 0s - loss: 2.3017 - mean_absolute_error: 1.2310 - val_loss: 0.5336 - val_mean_absolute_error: 0.5984 - 41ms/epoch - 3ms/step
# Epoch 43/50
# 15/15 - 0s - loss: 2.2701 - mean_absolute_error: 1.2221 - val_loss: 0.5221 - val_mean_absolute_error: 0.5899 - 45ms/epoch - 3ms/step
# Epoch 44/50
# 15/15 - 0s - loss: 2.2380 - mean_absolute_error: 1.2129 - val_loss: 0.5108 - val_mean_absolute_error: 0.5844 - 44ms/epoch - 3ms/step
# Epoch 45/50
# 15/15 - 0s - loss: 2.2081 - mean_absolute_error: 1.2044 - val_loss: 0.4999 - val_mean_absolute_error: 0.5821 - 46ms/epoch - 3ms/step
# Epoch 46/50
# 15/15 - 0s - loss: 2.1814 - mean_absolute_error: 1.1968 - val_loss: 0.4904 - val_mean_absolute_error: 0.5803 - 48ms/epoch - 3ms/step
# Epoch 47/50
# 15/15 - 0s - loss: 2.1560 - mean_absolute_error: 1.1892 - val_loss: 0.4825 - val_mean_absolute_error: 0.5781 - 46ms/epoch - 3ms/step
# Epoch 48/50
# 15/15 - 0s - loss: 2.1328 - mean_absolute_error: 1.1821 - val_loss: 0.4757 - val_mean_absolute_error: 0.5760 - 47ms/epoch - 3ms/step
# Epoch 49/50
# 15/15 - 0s - loss: 2.1099 - mean_absolute_error: 1.1753 - val_loss: 0.4699 - val_mean_absolute_error: 0.5733 - 48ms/epoch - 3ms/step
# Epoch 50/50
# 15/15 - 0s - loss: 2.0866 - mean_absolute_error: 1.1686 - val_loss: 0.4650 - val_mean_absolute_error: 0.5706 - 49ms/epoch - 3ms/step

# %%
#PREDICT THE VALUES USING THE MODEL
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()


fig,axs = plt.subplots(3, 1, figsize=(14,14))

axs[0].plot(dates_train, train_predictions)
axs[0].plot(dates_train, y_train)
axs[0].legend(['Training Predictions', 'Training Observations'])

axs[1].plot(dates_val, val_predictions)
axs[1].plot(dates_val, y_val)
axs[1].legend(['Validation Predictions', 'Validation Observations'])

axs[2].plot(dates_test, test_predictions)
axs[2].plot(dates_test, y_test)
axs[2].legend(['Testing Predictions', 'Testing Observations'])

plt.savefig('../analysis/LTSM_recursive/'+coin_name +'_modelPredictions'+'.png')

# %% [markdown]
# ## <font color='#5D6D7E'>Recursive Predictions</font> <a class="anchor" id="twentysixth-bullet"></a>
#   [Back to TOC](#toc)

# %%
from copy import deepcopy

#Get prediction for future dates recursively based on the previous existing information. Then update the window of days upon
#which the predictions are made

recursive_predictions = []
recursive_dates = np.concatenate([dates_test])

extra_dates = np.array(['2022-05-09', '2022-05-10', '2022-05-11'])
recursive_dates = np.append(recursive_dates,extra_dates)

last_window = deepcopy(X_train[-1])

for target_date in recursive_dates:
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window = np.insert(last_window,0,next_prediction)[:-1]

# %%
fig,axs = plt.subplots(2, 1, figsize=(14,10))

axs[0].plot(dates_train, train_predictions)
axs[0].plot(dates_train, y_train)
axs[0].plot(dates_val, val_predictions)
axs[0].plot(dates_val, y_val)
axs[0].plot(dates_test, test_predictions)
axs[0].plot(dates_test, y_test)
axs[0].plot(recursive_dates, recursive_predictions)
axs[0].legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

axs[1].plot(dates_test, y_test)
axs[1].plot(recursive_dates, recursive_predictions)
axs[1].legend(['Testing Observations',
              'Recursive Predictions'])

plt.savefig('../analysis/LTSM_recursive/'+coin_name +'_recursivePredictions'+'.png')

# %%
may_10_prediction = coin_name +'-USD',recursive_predictions[-2][0]
may_10_prediction
# Out:
# ('LINK-USD', 14.5048485)
