# %% [markdown]
# <!-- <div>
#     <img src="attachment:image.png" align="right" width="150">
# </div> -->
#
# # <font color='#5D6D7E '> <center >Forecasting - AXS</center>
#
# ### Master Degree Program in Data Science and Advanced Analytics
#
# ### <font color='#5D6D7E '> Business Cases with Data Science Project:
# > #### Group AA
#
# ### <font color='#5D6D7E '> Done by:
# > #### - Beatriz Martins Selidónio Gomes, m20210545
# > #### - Catarina Inês Lopes Garcez, m20210547
# > #### - Diogo André Domingues Pires, m20201076
# > #### - Rodrigo Faísca Guedes, m20210587

# %% [markdown]
# ---

# %% [markdown]
# <div>
#
# # Table of Content<a class="anchor"><a id='toc'></a>
#
# ### <font color='#5D6D7E '> Import and Data Integration
# - [<font color='#000000'>Import the needed Libraries</font>](#third-bullet)<br>
#
# ### <font color='#5D6D7E '> Data Exploration and Understanding
# - [<font color='#000000'>Initial Analysis (EDA - Exploratory Data Analysis)</font>](#fifth-bullet)<br>
# - [<font color='#000000'>Variables Distribution</font>](#seventh-bullet)<br>
#
# ### <font color='#5D6D7E '> Data Preparation
# - [<font color='#000000'>Data Transformation</font>](#eighth-bullet)<br>
#
# ### <font color='#5D6D7E '> Modelling
# - [<font color='#000000'>Building LSTM Model</font>](#twentysecond-bullet)<br>
# - [<font color='#000000'>Get Best Parameters for LSTM</font>](#twentythird-bullet)<br>
# - [<font color='#000000'>Run the LSTM Model and Get Predictions</font>](#twentyfourth-bullet)<br>
# - [<font color='#000000'>Recursive Predictions</font>](#twentysixth-bullet)<br>
#
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Import and Data Integration
#
#
# ## <font color='#5D6D7E '>Import the needed Libraries</font> <a class="anchor" id="third-bullet"></a>
#   [Back to TOC](#toc)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# # Remember: library imports are ALWAYS at the top of the script, no exceptions!
# import sqlite3
# import os
# import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()
# from math import ceil
# import matplotlib.cm as cm
# import joblib
# import random
# from collections import Counter
# import datetime

# from collections import Counter
# from sklearn.preprocessing import StandardScaler

# #  RFE and Models
# # explore the number of selected features for RFE
# from numpy import mean
# from numpy import std
# from sklearn.datasets import make_classification
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
# from sklearn.feature_selection import RFE
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.pipeline import Pipeline
# from matplotlib import pyplot
# # report which features were selected by RFE
# from sklearn.datasets import make_classification
# from sklearn.feature_selection import RFE
# from sklearn.tree import DecisionTreeClassifier
# import sklearn
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.linear_model import LinearRegression
# from sklearn.preprocessing import LabelEncoder
# from sklearn.feature_selection import SelectKBest, f_classif
# from sklearn.linear_model import LassoCV
# from sklearn import preprocessing
# from sklearn.preprocessing import RobustScaler
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import classification_report, confusion_matrix
# from sklearn.model_selection import KFold
# from sklearn.model_selection import RepeatedKFold
# from sklearn.linear_model import LogisticRegression
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import f1_score 
# from sklearn.metrics import precision_score
# from sklearn.metrics import recall_score
# from sklearn.svm import SVC
# from sklearn import metrics
# from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# # Data Exploration and Understanding
#
# ## <font color='#5D6D7E'>Initial Analysis (EDA - Exploratory Data Analysis) </font> <a class="anchor" id="fifth-bullet"></a>
#   [Back to TOC](#toc)

# %%
df = pd.read_csv('../data/data_aux/df_AXS.csv')
df
# Out:
#             Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 0     2017-04-26               NaN            NaN           NaN          NaN
# 1     2017-04-27               NaN            NaN           NaN          NaN
# 2     2017-04-28               NaN            NaN           NaN          NaN
# 3     2017-04-29               NaN            NaN           NaN          NaN
# 4     2017-04-30               NaN            NaN           NaN          NaN
# ...          ...               ...            ...           ...          ...
# 1821  2022-04-21         45.097389      45.097389     47.908173    44.620983
# 1822  2022-04-22         45.963348      45.963348     46.514893    44.898846
# 1823  2022-04-23         45.180782      45.180782     46.072273    45.054134
# 1824  2022-04-24         44.369541      44.369541     45.520817    44.332603
# 1825  2022-04-25         42.973213      42.973213     44.428181    40.350979
#
#       AXS-USD_OPEN  AXS-USD_VOLUME
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# ...            ...             ...
# 1821     46.146866     315254265.0
# 1822     45.084476     293223333.0
# 1823     45.955498     185825882.0
# 1824     45.171925     171259555.0
# 1825     44.373047     342114485.0
#
# [1826 rows x 7 columns]

# %% [markdown]
# ### Data Types

# %%
# Get to know the number of instances and Features, the DataTypes and if there are missing values in each Feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              1826 non-null   object
#  1   AXS-USD_ADJCLOSE  538 non-null    float64
#  2   AXS-USD_CLOSE     538 non-null    float64
#  3   AXS-USD_HIGH      538 non-null    float64
#  4   AXS-USD_LOW       538 non-null    float64
#  5   AXS-USD_OPEN      538 non-null    float64
#  6   AXS-USD_VOLUME    538 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 100.0+ KB

# %% [markdown]
# ### Missing Values

# %%
# Count the number of missing values for each Feature
df.isna().sum().to_frame().rename(columns={0: 'Count Missing Values'})
# Out:
#                   Count Missing Values
# Date                                 0
# AXS-USD_ADJCLOSE                  1288
# AXS-USD_CLOSE                     1288
# AXS-USD_HIGH                      1288
# AXS-USD_LOW                       1288
# AXS-USD_OPEN                      1288
# AXS-USD_VOLUME                    1288

# %% [markdown]
# ### Descriptive Statistics

# %%
# Descriptive Statistics Table
df.describe().T
# Out:
#                   count          mean           std            min  \
# AXS-USD_ADJCLOSE  538.0  4.368895e+01  4.521039e+01       0.135104
# AXS-USD_CLOSE     538.0  4.368895e+01  4.521039e+01       0.135104
# AXS-USD_HIGH      538.0  4.606852e+01  4.751994e+01       0.149547
# AXS-USD_LOW       538.0  4.164627e+01  4.345773e+01       0.123431
# AXS-USD_OPEN      538.0  4.362574e+01  4.527274e+01       0.135104
# AXS-USD_VOLUME    538.0  4.358642e+08  7.423602e+08  579626.000000
#
#                            25%           50%           75%           max
# AXS-USD_ADJCLOSE  3.787297e+00  4.237009e+01  6.965252e+01  1.603593e+02
# AXS-USD_CLOSE     3.787297e+00  4.237009e+01  6.965252e+01  1.603593e+02
# AXS-USD_HIGH      4.056442e+00  4.493683e+01  7.382753e+01  1.653691e+02
# AXS-USD_LOW       3.386940e+00  3.822049e+01  6.694265e+01  1.542171e+02
# AXS-USD_OPEN      3.740667e+00  4.228959e+01  6.962919e+01  1.606206e+02
# AXS-USD_VOLUME    2.186772e+07  2.372675e+08  5.276080e+08  6.680962e+09

# %%
# settings to display all columns
pd.set_option("display.max_columns", None)

# display the dataframe head
df.sample(n=10)
# Out:
#             Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 1265  2020-10-12               NaN            NaN           NaN          NaN
# 891   2019-10-04               NaN            NaN           NaN          NaN
# 797   2019-07-02               NaN            NaN           NaN          NaN
# 1002  2020-01-23               NaN            NaN           NaN          NaN
# 1347  2021-01-02          0.541321       0.541321      0.619981     0.532133
# 1379  2021-02-03          1.018777       1.018777      1.052682     0.949651
# 580   2018-11-27               NaN            NaN           NaN          NaN
# 956   2019-12-08               NaN            NaN           NaN          NaN
# 364   2018-04-25               NaN            NaN           NaN          NaN
# 411   2018-06-11               NaN            NaN           NaN          NaN
#
#       AXS-USD_OPEN  AXS-USD_VOLUME
# 1265           NaN             NaN
# 891            NaN             NaN
# 797            NaN             NaN
# 1002           NaN             NaN
# 1347      0.593076       8697336.0
# 1379      0.960150       8703562.0
# 580            NaN             NaN
# 956            NaN             NaN
# 364            NaN             NaN
# 411            NaN             NaN

# %%
#CHECK ROWS THAT HAVE ANY MISSING VALUE IN ONE OF THE COLUMNS
is_NaN = df.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = df[row_has_NaN]
rows_with_NaN
# Out:
#             Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 0     2017-04-26               NaN            NaN           NaN          NaN
# 1     2017-04-27               NaN            NaN           NaN          NaN
# 2     2017-04-28               NaN            NaN           NaN          NaN
# 3     2017-04-29               NaN            NaN           NaN          NaN
# 4     2017-04-30               NaN            NaN           NaN          NaN
# ...          ...               ...            ...           ...          ...
# 1283  2020-10-30               NaN            NaN           NaN          NaN
# 1284  2020-10-31               NaN            NaN           NaN          NaN
# 1285  2020-11-01               NaN            NaN           NaN          NaN
# 1286  2020-11-02               NaN            NaN           NaN          NaN
# 1287  2020-11-03               NaN            NaN           NaN          NaN
#
#       AXS-USD_OPEN  AXS-USD_VOLUME
# 0              NaN             NaN
# 1              NaN             NaN
# 2              NaN             NaN
# 3              NaN             NaN
# 4              NaN             NaN
# ...            ...             ...
# 1283           NaN             NaN
# 1284           NaN             NaN
# 1285           NaN             NaN
# 1286           NaN             NaN
# 1287           NaN             NaN
#
# [1288 rows x 7 columns]

# %%
#FILTER OUT ROWS THAT ARE MISSING INFORMATION
df = df[~row_has_NaN]
df.reset_index(inplace=True, drop=True)
df
# Out:
#            Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 0    2020-11-04          0.145949       0.145949      0.191121     0.141809
# 1    2020-11-05          0.135104       0.135104      0.150565     0.126469
# 2    2020-11-06          0.143164       0.143164      0.149547     0.123431
# 3    2020-11-07          0.141056       0.141056      0.168470     0.134455
# 4    2020-11-08          0.198251       0.198251      0.239455     0.139401
# ..          ...               ...            ...           ...          ...
# 533  2022-04-21         45.097389      45.097389     47.908173    44.620983
# 534  2022-04-22         45.963348      45.963348     46.514893    44.898846
# 535  2022-04-23         45.180782      45.180782     46.072273    45.054134
# 536  2022-04-24         44.369541      44.369541     45.520817    44.332603
# 537  2022-04-25         42.973213      42.973213     44.428181    40.350979
#
#      AXS-USD_OPEN  AXS-USD_VOLUME
# 0        0.179801      16344570.0
# 1        0.145951       4948417.0
# 2        0.135104       3148629.0
# 3        0.143189       1987416.0
# 4        0.141021       9484360.0
# ..            ...             ...
# 533     46.146866     315254265.0
# 534     45.084476     293223333.0
# 535     45.955498     185825882.0
# 536     45.171925     171259555.0
# 537     44.373047     342114485.0
#
# [538 rows x 7 columns]

# %% [markdown]
# # Data Preparation
#
#
# ## <font color='#5D6D7E'>Data Transformation</font> <a class="anchor" id="eighth-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
#  __`Duplicates`__

# %%
# Checking if exist duplicated observations
print(f'\033[1m' + "Number of duplicates: " + '\033[0m', df.duplicated().sum())
# Out:
# Number of duplicates:  0

# %% [markdown]
#  __`Convert Date to correct format`__

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df
# Out:
#           Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 0   2020-11-04          0.145949       0.145949      0.191121     0.141809
# 1   2020-11-05          0.135104       0.135104      0.150565     0.126469
# 2   2020-11-06          0.143164       0.143164      0.149547     0.123431
# 3   2020-11-07          0.141056       0.141056      0.168470     0.134455
# 4   2020-11-08          0.198251       0.198251      0.239455     0.139401
# ..         ...               ...            ...           ...          ...
# 533 2022-04-21         45.097389      45.097389     47.908173    44.620983
# 534 2022-04-22         45.963348      45.963348     46.514893    44.898846
# 535 2022-04-23         45.180782      45.180782     46.072273    45.054134
# 536 2022-04-24         44.369541      44.369541     45.520817    44.332603
# 537 2022-04-25         42.973213      42.973213     44.428181    40.350979
#
#      AXS-USD_OPEN  AXS-USD_VOLUME
# 0        0.179801      16344570.0
# 1        0.145951       4948417.0
# 2        0.135104       3148629.0
# 3        0.143189       1987416.0
# 4        0.141021       9484360.0
# ..            ...             ...
# 533     46.146866     315254265.0
# 534     45.084476     293223333.0
# 535     45.955498     185825882.0
# 536     45.171925     171259555.0
# 537     44.373047     342114485.0
#
# [538 rows x 7 columns]

# %% [markdown]
#  __`Get percentual difference between open and close values and low and high values`__

# %%
df['pctDiff_CloseOpen'] = abs((df[df.columns[2]]-df[df.columns[5]])/df[df.columns[2]])*100
df['pctDiff_HighLow'] = abs((df[df.columns[3]]-df[df.columns[4]])/df[df.columns[4]])*100
df.head()
# Out:
#         Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 0 2020-11-04          0.145949       0.145949      0.191121     0.141809
# 1 2020-11-05          0.135104       0.135104      0.150565     0.126469
# 2 2020-11-06          0.143164       0.143164      0.149547     0.123431
# 3 2020-11-07          0.141056       0.141056      0.168470     0.134455
# 4 2020-11-08          0.198251       0.198251      0.239455     0.139401
#
#    AXS-USD_OPEN  AXS-USD_VOLUME  pctDiff_CloseOpen  pctDiff_HighLow
# 0      0.179801      16344570.0          23.194400        34.773530
# 1      0.145951       4948417.0           8.028631        19.052888
# 2      0.135104       3148629.0           5.629903        21.158379
# 3      0.143189       1987416.0           1.512163        25.298428
# 4      0.141021       9484360.0          28.867445        71.774229

# %%
def plot_coinValue(df):
    
    #Get coin name
    coin_name = df.columns[2].split('-')[0]
    
    #Get date and coin value
    x = df['Date']
    y = df[df.columns[2]] # ADA-USD_CLOSE
    
    #Get the volume of trades
    v = df[df.columns[-3]]/1e9
    
    #Get percentual diferences
    y2 = df[df.columns[-1]] # pctDiff_HighLow
    y1= df[df.columns[-2]]  # pctDiff_CloseOpen
    
    fig, axs = plt.subplots(3, 1, figsize=(12,14))
    
    axs[0].plot(x, y)
    axs[2].plot(x, v)
    
    # plotting the line 1 points 
    axs[1].plot(x, y1, label = "Close/Open")

    # plotting the line 2 points 
    axs[1].plot(x, y2, label = "High/Low")
    axs[1].legend()
    
    axs[0].title.set_text('Time Evolution of '+ coin_name)
    axs[0].set(xlabel="", ylabel="Close Value in USD$")
    
    axs[2].title.set_text('Volume of trades of '+ coin_name)
    axs[2].set(xlabel="", ylabel="Total number of trades in billions")
    
    
    axs[1].title.set_text('Daily Market percentual differences of '+ coin_name)
    axs[1].set(xlabel="", ylabel="Percentage (%)")
    
    plt.savefig('../analysis/'+coin_name +'_stats'+'.png')
    
    return coin_name

# %%
coin_name = plot_coinValue(df)

# %%
#FILTER DATASET
df = df.loc[df['Date']>= '2021-10-01'] # 2021-07-01
df
# Out:
#           Date  AXS-USD_ADJCLOSE  AXS-USD_CLOSE  AXS-USD_HIGH  AXS-USD_LOW  \
# 331 2021-10-01        110.539093     110.539093    117.026787    74.249603
# 332 2021-10-02        107.941734     107.941734    119.921448   106.400620
# 333 2021-10-03        138.318146     138.318146    138.318146   103.990822
# 334 2021-10-04        133.951370     133.951370    155.084488   131.956909
# 335 2021-10-05        128.987259     128.987259    145.702011   127.531685
# ..         ...               ...            ...           ...          ...
# 533 2022-04-21         45.097389      45.097389     47.908173    44.620983
# 534 2022-04-22         45.963348      45.963348     46.514893    44.898846
# 535 2022-04-23         45.180782      45.180782     46.072273    45.054134
# 536 2022-04-24         44.369541      44.369541     45.520817    44.332603
# 537 2022-04-25         42.973213      42.973213     44.428181    40.350979
#
#      AXS-USD_OPEN  AXS-USD_VOLUME  pctDiff_CloseOpen  pctDiff_HighLow
# 331     74.611092    3.272757e+09          32.502530        57.612676
# 332    110.410843    2.587818e+09           2.287446        12.707471
# 333    107.963425    2.673087e+09          21.945581        33.009955
# 334    137.372620    3.964783e+09           2.554098        17.526614
# 335    134.723068    2.090557e+09           4.446803        14.247696
# ..            ...             ...                ...              ...
# 533     46.146866    3.152543e+08           2.327134         7.366914
# 534     45.084476    2.932233e+08           1.912115         3.599306
# 535     45.955498    1.858259e+08           1.714701         2.259812
# 536     45.171925    1.712596e+08           1.808410         2.680225
# 537     44.373047    3.421145e+08           3.257456        10.104344
#
# [207 rows x 9 columns]

# %% [markdown]
# # Modelling
#
#
# ## <font color='#5D6D7E'>Building LSTM Model</font> <a class="anchor" id="twentysecond-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
# ## Strategy
#
# Create a DF (windowed_df) where the middle columns will correspond to the close values of X days before the target date and the final column will correspond to the close value of the target date. Use these values for prediction and play with the value of X

# %%
def get_windowed_df(X, df):
    start_Date = df['Date'] + pd.Timedelta(days=X)
    
    perm = np.zeros((1,X+1))
    
    #Get labels for DataFrame
    j=1
    labels=[]
    
    while j <= X:
        label = 'closeValue_' + str(j) + 'daysBefore'
        labels.append(label)
        
        j+=1
 
    labels.append('closeValue')
    
    for i in range(X,df.shape[0]):
        temp = np.zeros((1,X+1))
        
        #Date for i-th day
        #temp[0,0] = df.iloc[i]['Date']
        
        #Close values for k days before
        for k in range(X):           
            temp[0,k] = df.iloc[i-k-1,2]
            
        #Close value for i-th date
        temp[0,-1] = df.iloc[i,2]
        

        #Add values to the permanent frame
        perm = np.vstack((perm,temp))
        
        #Get the array in dataframe form
        windowed_df = pd.DataFrame(perm[1:,:], columns = labels)
        
    return windowed_df

# %%
#Get the dataframe and append the dates
windowed_df = get_windowed_df(10, df)
windowed_df['Date'] = df.iloc[10:]['Date'].reset_index(drop=True)
windowed_df
# Out:
#      closeValue_1daysBefore  closeValue_2daysBefore  closeValue_3daysBefore  \
# 0                116.322701              126.545799              126.367287
# 1                117.017021              116.322701              126.545799
# 2                122.065582              117.017021              116.322701
# 3                121.766754              122.065582              117.017021
# 4                136.212082              121.766754              122.065582
# ..                      ...                     ...                     ...
# 192               46.147995               47.441418               46.212879
# 193               45.097389               46.147995               47.441418
# 194               45.963348               45.097389               46.147995
# 195               45.180782               45.963348               45.097389
# 196               44.369541               45.180782               45.963348
#
#      closeValue_4daysBefore  closeValue_5daysBefore  closeValue_6daysBefore  \
# 0                124.509331              126.216606              128.987259
# 1                126.367287              124.509331              126.216606
# 2                126.545799              126.367287              124.509331
# 3                116.322701              126.545799              126.367287
# 4                117.017021              116.322701              126.545799
# ..                      ...                     ...                     ...
# 192               45.541279               47.501385               47.938419
# 193               46.212879               45.541279               47.501385
# 194               47.441418               46.212879               45.541279
# 195               46.147995               47.441418               46.212879
# 196               45.097389               46.147995               47.441418
#
#      closeValue_7daysBefore  closeValue_8daysBefore  closeValue_9daysBefore  \
# 0                133.951370              138.318146              107.941734
# 1                128.987259              133.951370              138.318146
# 2                126.216606              128.987259              133.951370
# 3                124.509331              126.216606              128.987259
# 4                126.367287              124.509331              126.216606
# ..                      ...                     ...                     ...
# 192               46.771194               48.443615               47.346897
# 193               47.938419               46.771194               48.443615
# 194               47.501385               47.938419               46.771194
# 195               45.541279               47.501385               47.938419
# 196               46.212879               45.541279               47.501385
#
#      closeValue_10daysBefore  closeValue       Date
# 0                 110.539093  117.017021 2021-10-11
# 1                 107.941734  122.065582 2021-10-12
# 2                 138.318146  121.766754 2021-10-13
# 3                 133.951370  136.212082 2021-10-14
# 4                 128.987259  125.787872 2021-10-15
# ..                       ...         ...        ...
# 192                45.047264   45.097389 2022-04-21
# 193                47.346897   45.963348 2022-04-22
# 194                48.443615   45.180782 2022-04-23
# 195                46.771194   44.369541 2022-04-24
# 196                47.938419   42.973213 2022-04-25
#
# [197 rows x 12 columns]

# %%
#Get the X,y and dates into a numpy array to apply on a model

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    dates = df_as_np[:, -1]

    middle_matrix = df_as_np[:, 0:-2]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    Y = df_as_np[:, -2]

    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((197,), (197, 10, 1), (197,))

# %%
#Partition for train, validation and test

q_80 = int(len(dates) * .85)
q_90 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

fig,axs = plt.subplots(1, 1, figsize=(12,5))

#Plot the partitions
axs.plot(dates_train, y_train)
axs.plot(dates_val, y_val)
axs.plot(dates_test, y_test)

axs.legend(['Train', 'Validation', 'Test'])

fig.savefig('../analysis/'+coin_name +'_partition'+'.png')

# %% [markdown]
# ## <font color='#5D6D7E'>Get Best Parameters for LSTM</font> <a class="anchor" id="twentythird-bullet"></a>
#   [Back to TOC](#toc)

# %%
#!pip install tensorflow

# %%
#import os
#os.environ['PYTHONHASHSEED']= '0'
#import numpy as np
#np.random.seed(1)
#import random as rn
#rn.seed(1)
#import tensorflow as tf
#tf.random.set_seed(1)
#
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.optimizers import Adam
#from tensorflow.keras import layers
#from sklearn.metrics import mean_squared_error
#
## Function to create LSTM model and compute the MSE value for the given parameters
#def check_model(X_train, y_train, X_val, y_val, X_test, y_test, learning_rate,epoch,batch):
#    
#    # create model
#    model = Sequential([layers.Input((10, 1)),
#                        layers.LSTM(64),
#                        layers.Dense(32, activation='relu'),
#                        layers.Dense(32, activation='relu'),
#                        layers.Dense(1)])
#    # Compile model
#    model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate), metrics=['mean_absolute_error'])
#    
#    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epoch, shuffle=False, batch_size=batch, verbose=2)
#    
#    test_predictions = model.predict(X_test).flatten()
#    
#    LSTM_mse = mean_squared_error(y_test, test_predictions)
#    
#    return LSTM_mse
#
##Function that iterates the different parameters and gets the ones corresponding to the lowest MSE score.
#def search_parameters(batch_size, epochs, learn_rate, X_train, y_train, X_val, y_val, X_test, y_test):
#    
#    best_score = float('inf')
#    
#    for b in batch_size:
#        for e in epochs:
#            for l in learn_rate:
#                print('Batch Size: ' + str(b))
#                print('Number of Epochs: ' + str(e))
#                print('Value of Learning Rate: ' + str(l))
#                try:
#                    mse = check_model(X_train, y_train, X_val, y_val, X_test, y_test,l,e,b)
#                    print('MSE=%.3f' % (mse))
#                    if mse < best_score:
#                        best_score = mse
#                        top_params = [b, e, l]
#                except:
#                    continue
#                    
#    print('Best MSE=%.3f' % (best_score))
#    print('Optimal Batch Size: ' + str(top_params[0]))
#    print('Optimal Number of Epochs: ' + str(top_params[1]))
#    print('Optimal Value of Learning Rate: ' + str(top_params[2]))
#                        
#
## define parameters
#batch_size = [10, 100, 1000]
#epochs = [50, 100]
#learn_rate = np.linspace(0.001,0.1, num=10)
#
#warnings.filterwarnings("ignore")
#search_parameters(batch_size, epochs, learn_rate, X_train, y_train, X_val, y_val, X_test, y_test)

# %% [markdown]
# ## <font color='#5D6D7E'>Run the LSTM Model and Get Predictions</font> <a class="anchor" id="twentyfourth-bullet"></a>
#   [Back to TOC](#toc)

# %%
#BEST SOLUTION OF THE MODEL

# MSE=29.138
# Batch Size: 100
# Number of Epochs: 100
# Value of Learning Rate: 0.012
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error

model = Sequential([layers.Input((10, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.012),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, shuffle=False, batch_size=100, verbose=2)
# Out:
# Epoch 1/100
# 2/2 - 1s - loss: 9496.5576 - mean_absolute_error: 90.5907 - val_loss: 3130.2195 - val_mean_absolute_error: 55.3576 - 1s/epoch - 725ms/step
# Epoch 2/100
# 2/2 - 0s - loss: 9135.1074 - mean_absolute_error: 88.5409 - val_loss: 2818.3042 - val_mean_absolute_error: 52.4673 - 26ms/epoch - 13ms/step
# Epoch 3/100
# 2/2 - 0s - loss: 8614.8096 - mean_absolute_error: 85.3331 - val_loss: 2335.0630 - val_mean_absolute_error: 47.6428 - 28ms/epoch - 14ms/step
# Epoch 4/100
# 2/2 - 0s - loss: 7789.4805 - mean_absolute_error: 80.0697 - val_loss: 1678.6569 - val_mean_absolute_error: 40.1814 - 27ms/epoch - 14ms/step
# Epoch 5/100
# 2/2 - 0s - loss: 6738.5840 - mean_absolute_error: 72.4970 - val_loss: 898.9650 - val_mean_absolute_error: 28.9000 - 27ms/epoch - 13ms/step
# Epoch 6/100
# 2/2 - 0s - loss: 5356.4917 - mean_absolute_error: 61.2040 - val_loss: 243.1429 - val_mean_absolute_error: 13.3833 - 28ms/epoch - 14ms/step
# Epoch 7/100
# 2/2 - 0s - loss: 3742.1702 - mean_absolute_error: 47.1847 - val_loss: 100.5292 - val_mean_absolute_error: 7.8035 - 28ms/epoch - 14ms/step
# Epoch 8/100
# 2/2 - 0s - loss: 2404.8586 - mean_absolute_error: 41.2904 - val_loss: 698.6999 - val_mean_absolute_error: 25.1817 - 27ms/epoch - 14ms/step
# Epoch 9/100
# 2/2 - 0s - loss: 1643.3640 - mean_absolute_error: 36.8492 - val_loss: 1757.8707 - val_mean_absolute_error: 41.1413 - 26ms/epoch - 13ms/step
# Epoch 10/100
# 2/2 - 0s - loss: 1574.8252 - mean_absolute_error: 35.1939 - val_loss: 2517.0239 - val_mean_absolute_error: 49.5087 - 27ms/epoch - 14ms/step
# Epoch 11/100
# 2/2 - 0s - loss: 1593.3925 - mean_absolute_error: 34.9183 - val_loss: 2483.7363 - val_mean_absolute_error: 49.1456 - 28ms/epoch - 14ms/step
# Epoch 12/100
# 2/2 - 0s - loss: 1384.5363 - mean_absolute_error: 32.9006 - val_loss: 1770.3445 - val_mean_absolute_error: 41.2450 - 27ms/epoch - 13ms/step
# Epoch 13/100
# 2/2 - 0s - loss: 1120.6672 - mean_absolute_error: 30.0590 - val_loss: 1110.0208 - val_mean_absolute_error: 32.3023 - 27ms/epoch - 14ms/step
# Epoch 14/100
# 2/2 - 0s - loss: 1136.0168 - mean_absolute_error: 30.3283 - val_loss: 715.3953 - val_mean_absolute_error: 25.4833 - 29ms/epoch - 15ms/step
# Epoch 15/100
# 2/2 - 0s - loss: 1234.6735 - mean_absolute_error: 30.9835 - val_loss: 486.9714 - val_mean_absolute_error: 20.5356 - 27ms/epoch - 14ms/step
# Epoch 16/100
# 2/2 - 0s - loss: 1384.9214 - mean_absolute_error: 31.9115 - val_loss: 387.6214 - val_mean_absolute_error: 17.9413 - 29ms/epoch - 15ms/step
# Epoch 17/100
# 2/2 - 0s - loss: 1394.4495 - mean_absolute_error: 31.6761 - val_loss: 383.1287 - val_mean_absolute_error: 17.7281 - 29ms/epoch - 15ms/step
# Epoch 18/100
# 2/2 - 0s - loss: 1412.6066 - mean_absolute_error: 31.9519 - val_loss: 437.2134 - val_mean_absolute_error: 19.1249 - 29ms/epoch - 15ms/step
# Epoch 19/100
# 2/2 - 0s - loss: 1412.2218 - mean_absolute_error: 32.2731 - val_loss: 515.7927 - val_mean_absolute_error: 21.0424 - 29ms/epoch - 15ms/step
# Epoch 20/100
# 2/2 - 0s - loss: 1374.8926 - mean_absolute_error: 32.2229 - val_loss: 589.7713 - val_mean_absolute_error: 22.6717 - 28ms/epoch - 14ms/step
# Epoch 21/100
# 2/2 - 0s - loss: 1302.6584 - mean_absolute_error: 31.6392 - val_loss: 559.8241 - val_mean_absolute_error: 22.1976 - 29ms/epoch - 15ms/step
# Epoch 22/100
# 2/2 - 0s - loss: 1200.6060 - mean_absolute_error: 30.4495 - val_loss: 584.1973 - val_mean_absolute_error: 22.7826 - 29ms/epoch - 15ms/step
# Epoch 23/100
# 2/2 - 0s - loss: 1143.5002 - mean_absolute_error: 29.8558 - val_loss: 683.8693 - val_mean_absolute_error: 24.8583 - 28ms/epoch - 14ms/step
# Epoch 24/100
# 2/2 - 0s - loss: 1113.9797 - mean_absolute_error: 30.0874 - val_loss: 776.1190 - val_mean_absolute_error: 26.6467 - 29ms/epoch - 15ms/step
# Epoch 25/100
# 2/2 - 0s - loss: 1073.0436 - mean_absolute_error: 29.6565 - val_loss: 839.1338 - val_mean_absolute_error: 27.8042 - 28ms/epoch - 14ms/step
# Epoch 26/100
# 2/2 - 0s - loss: 1038.6835 - mean_absolute_error: 29.1204 - val_loss: 860.8252 - val_mean_absolute_error: 28.1924 - 28ms/epoch - 14ms/step
# Epoch 27/100
# 2/2 - 0s - loss: 997.8666 - mean_absolute_error: 27.9665 - val_loss: 835.0170 - val_mean_absolute_error: 27.7318 - 27ms/epoch - 14ms/step
# Epoch 28/100
# 2/2 - 0s - loss: 979.4869 - mean_absolute_error: 27.7081 - val_loss: 772.2976 - val_mean_absolute_error: 26.5772 - 29ms/epoch - 15ms/step
# Epoch 29/100
# 2/2 - 0s - loss: 964.2563 - mean_absolute_error: 27.4666 - val_loss: 691.5506 - val_mean_absolute_error: 25.0111 - 29ms/epoch - 15ms/step
# Epoch 30/100
# 2/2 - 0s - loss: 949.4521 - mean_absolute_error: 27.0936 - val_loss: 611.2526 - val_mean_absolute_error: 23.3496 - 29ms/epoch - 15ms/step
# Epoch 31/100
# 2/2 - 0s - loss: 941.0769 - mean_absolute_error: 26.7395 - val_loss: 544.2621 - val_mean_absolute_error: 21.8673 - 29ms/epoch - 15ms/step
# Epoch 32/100
# 2/2 - 0s - loss: 936.5583 - mean_absolute_error: 26.4261 - val_loss: 497.7820 - val_mean_absolute_error: 20.7778 - 27ms/epoch - 14ms/step
# Epoch 33/100
# 2/2 - 0s - loss: 930.6230 - mean_absolute_error: 26.1993 - val_loss: 470.7366 - val_mean_absolute_error: 20.1171 - 28ms/epoch - 14ms/step
# Epoch 34/100
# 2/2 - 0s - loss: 920.4413 - mean_absolute_error: 25.9659 - val_loss: 460.7388 - val_mean_absolute_error: 19.8675 - 28ms/epoch - 14ms/step
# Epoch 35/100
# 2/2 - 0s - loss: 904.3991 - mean_absolute_error: 25.6862 - val_loss: 464.6951 - val_mean_absolute_error: 19.9675 - 27ms/epoch - 14ms/step
# Epoch 36/100
# 2/2 - 0s - loss: 883.7867 - mean_absolute_error: 25.4782 - val_loss: 475.7055 - val_mean_absolute_error: 20.2415 - 29ms/epoch - 15ms/step
# Epoch 37/100
# 2/2 - 0s - loss: 858.4103 - mean_absolute_error: 25.1229 - val_loss: 488.0971 - val_mean_absolute_error: 20.5437 - 27ms/epoch - 14ms/step
# Epoch 38/100
# 2/2 - 0s - loss: 826.2070 - mean_absolute_error: 24.5740 - val_loss: 496.0373 - val_mean_absolute_error: 20.7227 - 25ms/epoch - 13ms/step
# Epoch 39/100
# 2/2 - 0s - loss: 811.3166 - mean_absolute_error: 24.6300 - val_loss: 491.7282 - val_mean_absolute_error: 20.5913 - 24ms/epoch - 12ms/step
# Epoch 40/100
# 2/2 - 0s - loss: 760.6217 - mean_absolute_error: 23.6589 - val_loss: 459.0781 - val_mean_absolute_error: 19.8131 - 24ms/epoch - 12ms/step
# Epoch 41/100
# 2/2 - 0s - loss: 728.3729 - mean_absolute_error: 23.1257 - val_loss: 430.5636 - val_mean_absolute_error: 19.0490 - 25ms/epoch - 13ms/step
# Epoch 42/100
# 2/2 - 0s - loss: 717.9510 - mean_absolute_error: 22.7446 - val_loss: 385.6351 - val_mean_absolute_error: 17.8333 - 25ms/epoch - 13ms/step
# Epoch 43/100
# 2/2 - 0s - loss: 663.7928 - mean_absolute_error: 21.6681 - val_loss: 357.9880 - val_mean_absolute_error: 17.0682 - 24ms/epoch - 12ms/step
# Epoch 44/100
# 2/2 - 0s - loss: 647.2032 - mean_absolute_error: 21.5180 - val_loss: 369.2656 - val_mean_absolute_error: 17.3032 - 25ms/epoch - 13ms/step
# Epoch 45/100
# 2/2 - 0s - loss: 617.3944 - mean_absolute_error: 21.1699 - val_loss: 334.9182 - val_mean_absolute_error: 16.3809 - 26ms/epoch - 13ms/step
# Epoch 46/100
# 2/2 - 0s - loss: 580.1092 - mean_absolute_error: 20.6190 - val_loss: 294.2603 - val_mean_absolute_error: 15.1053 - 26ms/epoch - 13ms/step
# Epoch 47/100
# 2/2 - 0s - loss: 548.6782 - mean_absolute_error: 19.9077 - val_loss: 269.3782 - val_mean_absolute_error: 14.2417 - 25ms/epoch - 13ms/step
# Epoch 48/100
# 2/2 - 0s - loss: 517.1929 - mean_absolute_error: 19.1095 - val_loss: 244.7054 - val_mean_absolute_error: 13.3482 - 25ms/epoch - 13ms/step
# Epoch 49/100
# 2/2 - 0s - loss: 478.6482 - mean_absolute_error: 18.0940 - val_loss: 225.3879 - val_mean_absolute_error: 12.6053 - 24ms/epoch - 12ms/step
# Epoch 50/100
# 2/2 - 0s - loss: 520.5693 - mean_absolute_error: 19.6244 - val_loss: 223.5979 - val_mean_absolute_error: 12.4854 - 25ms/epoch - 13ms/step
# Epoch 51/100
# 2/2 - 0s - loss: 419.7650 - mean_absolute_error: 17.2034 - val_loss: 200.8343 - val_mean_absolute_error: 11.5019 - 25ms/epoch - 13ms/step
# Epoch 52/100
# 2/2 - 0s - loss: 392.1101 - mean_absolute_error: 16.7365 - val_loss: 173.7401 - val_mean_absolute_error: 10.4398 - 26ms/epoch - 13ms/step
# Epoch 53/100
# 2/2 - 0s - loss: 361.6748 - mean_absolute_error: 16.1737 - val_loss: 164.1080 - val_mean_absolute_error: 10.0196 - 24ms/epoch - 12ms/step
# Epoch 54/100
# 2/2 - 0s - loss: 345.7277 - mean_absolute_error: 15.7984 - val_loss: 154.5832 - val_mean_absolute_error: 9.5724 - 25ms/epoch - 13ms/step
# Epoch 55/100
# 2/2 - 0s - loss: 331.1868 - mean_absolute_error: 15.6507 - val_loss: 155.1554 - val_mean_absolute_error: 9.5821 - 25ms/epoch - 13ms/step
# Epoch 56/100
# 2/2 - 0s - loss: 300.0020 - mean_absolute_error: 14.9820 - val_loss: 145.6148 - val_mean_absolute_error: 9.1990 - 24ms/epoch - 12ms/step
# Epoch 57/100
# 2/2 - 0s - loss: 275.9336 - mean_absolute_error: 14.2576 - val_loss: 132.1479 - val_mean_absolute_error: 8.7219 - 26ms/epoch - 13ms/step
# Epoch 58/100
# 2/2 - 0s - loss: 261.6931 - mean_absolute_error: 14.0217 - val_loss: 129.3297 - val_mean_absolute_error: 8.6365 - 28ms/epoch - 14ms/step
# Epoch 59/100
# 2/2 - 0s - loss: 237.5758 - mean_absolute_error: 13.3517 - val_loss: 130.4979 - val_mean_absolute_error: 8.6807 - 26ms/epoch - 13ms/step
# Epoch 60/100
# 2/2 - 0s - loss: 213.2159 - mean_absolute_error: 12.5934 - val_loss: 130.4092 - val_mean_absolute_error: 8.6834 - 23ms/epoch - 12ms/step
# Epoch 61/100
# 2/2 - 0s - loss: 194.2598 - mean_absolute_error: 12.0337 - val_loss: 122.5561 - val_mean_absolute_error: 8.5387 - 24ms/epoch - 12ms/step
# Epoch 62/100
# 2/2 - 0s - loss: 173.5339 - mean_absolute_error: 11.2191 - val_loss: 97.2496 - val_mean_absolute_error: 8.1488 - 25ms/epoch - 13ms/step
# Epoch 63/100
# 2/2 - 0s - loss: 158.5709 - mean_absolute_error: 10.6095 - val_loss: 77.4947 - val_mean_absolute_error: 7.8294 - 25ms/epoch - 13ms/step
# Epoch 64/100
# 2/2 - 0s - loss: 156.1785 - mean_absolute_error: 10.4507 - val_loss: 72.5055 - val_mean_absolute_error: 7.8067 - 25ms/epoch - 13ms/step
# Epoch 65/100
# 2/2 - 0s - loss: 150.3484 - mean_absolute_error: 10.2472 - val_loss: 71.4678 - val_mean_absolute_error: 7.8253 - 25ms/epoch - 13ms/step
# Epoch 66/100
# 2/2 - 0s - loss: 132.1556 - mean_absolute_error: 9.6502 - val_loss: 73.2767 - val_mean_absolute_error: 7.8925 - 24ms/epoch - 12ms/step
# Epoch 67/100
# 2/2 - 0s - loss: 485.2249 - mean_absolute_error: 17.1746 - val_loss: 89.5134 - val_mean_absolute_error: 8.0445 - 24ms/epoch - 12ms/step
# Epoch 68/100
# 2/2 - 0s - loss: 398.0966 - mean_absolute_error: 15.2136 - val_loss: 88.8211 - val_mean_absolute_error: 8.2037 - 24ms/epoch - 12ms/step
# Epoch 69/100
# 2/2 - 0s - loss: 361.2417 - mean_absolute_error: 14.1985 - val_loss: 81.0035 - val_mean_absolute_error: 8.4085 - 25ms/epoch - 13ms/step
# Epoch 70/100
# 2/2 - 0s - loss: 162.3389 - mean_absolute_error: 10.4105 - val_loss: 81.0137 - val_mean_absolute_error: 8.5353 - 25ms/epoch - 13ms/step
# Epoch 71/100
# 2/2 - 0s - loss: 282.2898 - mean_absolute_error: 13.4119 - val_loss: 83.0896 - val_mean_absolute_error: 8.6318 - 24ms/epoch - 12ms/step
# Epoch 72/100
# 2/2 - 0s - loss: 148.3817 - mean_absolute_error: 9.8258 - val_loss: 84.3502 - val_mean_absolute_error: 8.6816 - 25ms/epoch - 13ms/step
# Epoch 73/100
# 2/2 - 0s - loss: 191.4569 - mean_absolute_error: 10.8849 - val_loss: 85.2446 - val_mean_absolute_error: 8.6699 - 24ms/epoch - 12ms/step
# Epoch 74/100
# 2/2 - 0s - loss: 162.2608 - mean_absolute_error: 9.9909 - val_loss: 86.6678 - val_mean_absolute_error: 8.6114 - 24ms/epoch - 12ms/step
# Epoch 75/100
# 2/2 - 0s - loss: 163.2666 - mean_absolute_error: 10.0446 - val_loss: 85.9104 - val_mean_absolute_error: 8.5404 - 25ms/epoch - 13ms/step
# Epoch 76/100
# 2/2 - 0s - loss: 163.2845 - mean_absolute_error: 10.1201 - val_loss: 82.8075 - val_mean_absolute_error: 8.4688 - 25ms/epoch - 13ms/step
# Epoch 77/100
# 2/2 - 0s - loss: 139.3687 - mean_absolute_error: 9.2496 - val_loss: 80.4290 - val_mean_absolute_error: 8.3911 - 25ms/epoch - 13ms/step
# Epoch 78/100
# 2/2 - 0s - loss: 142.0299 - mean_absolute_error: 9.3573 - val_loss: 79.1164 - val_mean_absolute_error: 8.2928 - 24ms/epoch - 12ms/step
# Epoch 79/100
# 2/2 - 0s - loss: 125.7214 - mean_absolute_error: 8.8860 - val_loss: 78.8485 - val_mean_absolute_error: 8.1972 - 24ms/epoch - 12ms/step
# Epoch 80/100
# 2/2 - 0s - loss: 171.5564 - mean_absolute_error: 9.8977 - val_loss: 75.7258 - val_mean_absolute_error: 8.1380 - 24ms/epoch - 12ms/step
# Epoch 81/100
# 2/2 - 0s - loss: 124.5614 - mean_absolute_error: 8.8973 - val_loss: 73.0759 - val_mean_absolute_error: 8.0730 - 25ms/epoch - 13ms/step
# Epoch 82/100
# 2/2 - 0s - loss: 137.4611 - mean_absolute_error: 9.1348 - val_loss: 72.2150 - val_mean_absolute_error: 7.9997 - 25ms/epoch - 13ms/step
# Epoch 83/100
# 2/2 - 0s - loss: 150.6641 - mean_absolute_error: 9.3073 - val_loss: 74.0036 - val_mean_absolute_error: 7.9332 - 25ms/epoch - 13ms/step
# Epoch 84/100
# 2/2 - 0s - loss: 156.7243 - mean_absolute_error: 9.4680 - val_loss: 78.6616 - val_mean_absolute_error: 7.9399 - 24ms/epoch - 12ms/step
# Epoch 85/100
# 2/2 - 0s - loss: 154.0853 - mean_absolute_error: 9.3389 - val_loss: 84.8385 - val_mean_absolute_error: 8.0208 - 25ms/epoch - 13ms/step
# Epoch 86/100
# 2/2 - 0s - loss: 147.9948 - mean_absolute_error: 9.0288 - val_loss: 91.4524 - val_mean_absolute_error: 8.1173 - 24ms/epoch - 12ms/step
# Epoch 87/100
# 2/2 - 0s - loss: 146.4086 - mean_absolute_error: 8.9903 - val_loss: 96.2677 - val_mean_absolute_error: 8.2184 - 25ms/epoch - 13ms/step
# Epoch 88/100
# 2/2 - 0s - loss: 144.1682 - mean_absolute_error: 8.9204 - val_loss: 96.5648 - val_mean_absolute_error: 8.2449 - 25ms/epoch - 13ms/step
# Epoch 89/100
# 2/2 - 0s - loss: 140.6591 - mean_absolute_error: 8.8858 - val_loss: 92.0191 - val_mean_absolute_error: 8.2731 - 24ms/epoch - 12ms/step
# Epoch 90/100
# 2/2 - 0s - loss: 135.6315 - mean_absolute_error: 8.7984 - val_loss: 85.9590 - val_mean_absolute_error: 8.3299 - 24ms/epoch - 12ms/step
# Epoch 91/100
# 2/2 - 0s - loss: 128.7860 - mean_absolute_error: 8.6926 - val_loss: 81.3467 - val_mean_absolute_error: 8.4217 - 25ms/epoch - 13ms/step
# Epoch 92/100
# 2/2 - 0s - loss: 124.2342 - mean_absolute_error: 8.6520 - val_loss: 78.8034 - val_mean_absolute_error: 8.4286 - 25ms/epoch - 13ms/step
# Epoch 93/100
# 2/2 - 0s - loss: 123.5497 - mean_absolute_error: 8.7509 - val_loss: 77.9525 - val_mean_absolute_error: 8.4118 - 26ms/epoch - 13ms/step
# Epoch 94/100
# 2/2 - 0s - loss: 123.0051 - mean_absolute_error: 8.8053 - val_loss: 78.0837 - val_mean_absolute_error: 8.4081 - 27ms/epoch - 14ms/step
# Epoch 95/100
# 2/2 - 0s - loss: 118.0369 - mean_absolute_error: 8.6695 - val_loss: 78.1006 - val_mean_absolute_error: 8.4070 - 25ms/epoch - 13ms/step
# Epoch 96/100
# 2/2 - 0s - loss: 112.0151 - mean_absolute_error: 8.4513 - val_loss: 77.1486 - val_mean_absolute_error: 8.3601 - 24ms/epoch - 12ms/step
# Epoch 97/100
# 2/2 - 0s - loss: 106.1977 - mean_absolute_error: 8.2464 - val_loss: 75.5615 - val_mean_absolute_error: 8.2302 - 24ms/epoch - 12ms/step
# Epoch 98/100
# 2/2 - 0s - loss: 103.6614 - mean_absolute_error: 8.2094 - val_loss: 74.1477 - val_mean_absolute_error: 8.0642 - 26ms/epoch - 13ms/step
# Epoch 99/100
# 2/2 - 0s - loss: 106.7317 - mean_absolute_error: 8.2090 - val_loss: 73.2393 - val_mean_absolute_error: 7.9380 - 25ms/epoch - 13ms/step
# Epoch 100/100
# 2/2 - 0s - loss: 108.8332 - mean_absolute_error: 8.1576 - val_loss: 73.5387 - val_mean_absolute_error: 7.8680 - 24ms/epoch - 12ms/step

# %%
#PREDICT THE VALUES USING THE MODEL
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()


fig,axs = plt.subplots(3, 1, figsize=(14,14))

axs[0].plot(dates_train, train_predictions)
axs[0].plot(dates_train, y_train)
axs[0].legend(['Training Predictions', 'Training Observations'])

axs[1].plot(dates_val, val_predictions)
axs[1].plot(dates_val, y_val)
axs[1].legend(['Validation Predictions', 'Validation Observations'])

axs[2].plot(dates_test, test_predictions)
axs[2].plot(dates_test, y_test)
axs[2].legend(['Testing Predictions', 'Testing Observations'])

plt.savefig('../analysis/LTSM_recursive/'+coin_name +'_modelPredictions'+'.png')

# %% [markdown]
# ## <font color='#5D6D7E'>Recursive Predictions</font> <a class="anchor" id="twentysixth-bullet"></a>
#   [Back to TOC](#toc)

# %%
from copy import deepcopy

#Get prediction for future dates recursively based on the previous existing information. Then update the window of days upon
#which the predictions are made

recursive_predictions = []
recursive_dates = np.concatenate([dates_test])

extra_dates = np.array(['2022-05-09', '2022-05-10', '2022-05-11'])
recursive_dates = np.append(recursive_dates,extra_dates)

last_window = deepcopy(X_train[-1])

for target_date in recursive_dates:
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window = np.insert(last_window,0,next_prediction)[:-1]

# %%
fig,axs = plt.subplots(2, 1, figsize=(14,10))

axs[0].plot(dates_train, train_predictions)
axs[0].plot(dates_train, y_train)
axs[0].plot(dates_val, val_predictions)
axs[0].plot(dates_val, y_val)
axs[0].plot(dates_test, test_predictions)
axs[0].plot(dates_test, y_test)
axs[0].plot(recursive_dates, recursive_predictions)
axs[0].legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations',
            'Recursive Predictions'])

axs[1].plot(dates_test, y_test)
axs[1].plot(recursive_dates, recursive_predictions)
axs[1].legend(['Testing Observations',
              'Recursive Predictions'])

plt.savefig('../analysis/LTSM_recursive/'+coin_name +'_recursivePredictions'+'.png')

# %%
may_10_prediction = coin_name +'-USD',recursive_predictions[-2][0]
may_10_prediction
# Out:
# ('AXS-USD', 54.447163)
