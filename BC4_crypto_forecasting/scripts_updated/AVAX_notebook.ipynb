# %% [markdown]
# <!-- <div>
#     <img src="attachment:image.png" align="right" width="150">
# </div> -->
#
# # <font color='#5D6D7E '> <center >Forecasting - AVAX</center>
#
# ### Master Degree Program in Data Science and Advanced Analytics
#
# ### <font color='#5D6D7E '> Business Cases with Data Science Project:
# > #### Group AA
#
# ### <font color='#5D6D7E '> Done by:
# > #### - Beatriz Martins Selidónio Gomes, m20210545
# > #### - Catarina Inês Lopes Garcez, m20210547
# > #### - Diogo André Domingues Pires, m20201076
# > #### - Rodrigo Faísca Guedes, m20210587

# %% [markdown]
# ---

# %% [markdown]
# <div>
#
# # Table of Content<a class="anchor"><a id='toc'></a>
#
# ### <font color='#5D6D7E '> Import and Data Integration
# - [<font color='#000000'>Import the needed Libraries</font>](#third-bullet)<br>
#
# ### <font color='#5D6D7E '> Data Exploration and Understanding
# - [<font color='#000000'>Initial Analysis (EDA - Exploratory Data Analysis)</font>](#fifth-bullet)<br>
# - [<font color='#000000'>Variables Distribution</font>](#seventh-bullet)<br>
#
# ### <font color='#5D6D7E '> Data Preparation
# - [<font color='#000000'>Data Transformation</font>](#eighth-bullet)<br>
#
# ### <font color='#5D6D7E '> Modelling
# - [<font color='#000000'>Building LSTM Model</font>](#twentysecond-bullet)<br>
# - [<font color='#000000'>Get Best Parameters for LSTM</font>](#twentythird-bullet)<br>
# - [<font color='#000000'>Run the LSTM Model and Get Predictions</font>](#twentyfourth-bullet)<br>
# - [<font color='#000000'>Recursive Predictions</font>](#twentysixth-bullet)<br>
#
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# # Import and Data Integration
#
#
# ## <font color='#5D6D7E '>Import the needed Libraries</font> <a class="anchor" id="third-bullet"></a>
#   [Back to TOC](#toc)

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Exploration and Understanding
#
# ## <font color='#5D6D7E'>Initial Analysis (EDA - Exploratory Data Analysis) </font> <a class="anchor" id="fifth-bullet"></a>
#   [Back to TOC](#toc)

# %%
df = pd.read_csv('../data/data_aux/df_AVAX.csv')
df
# Out:
#             Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  \
# 0     2017-04-26                NaN             NaN            NaN
# 1     2017-04-27                NaN             NaN            NaN
# 2     2017-04-28                NaN             NaN            NaN
# 3     2017-04-29                NaN             NaN            NaN
# 4     2017-04-30                NaN             NaN            NaN
# ...          ...                ...             ...            ...
# 1821  2022-04-21          75.080742       75.080742      80.008301
# 1822  2022-04-22          74.122963       74.122963      77.152420
# 1823  2022-04-23          72.920013       72.920013      74.369293
# 1824  2022-04-24          71.603035       71.603035      73.437004
# 1825  2022-04-25          72.867424       72.867424      72.904549
#
#       AVAX-USD_LOW  AVAX-USD_OPEN  AVAX-USD_VOLUME
# 0              NaN            NaN              NaN
# 1              NaN            NaN              NaN
# 2              NaN            NaN              NaN
# 3              NaN            NaN              NaN
# 4              NaN            NaN              NaN
# ...            ...            ...              ...
# 1821     74.412254      78.268646      569385150.0
# 1822     73.490158      75.084648      532238762.0
# 1823     72.632584      74.127480      360787956.0
# 1824     71.342026      72.892731      320340266.0
# 1825     67.563889      71.606567      735322462.0
#
# [1826 rows x 7 columns]

# %% [markdown]
# ### Data Types

# %%
# Get to know the number of instances and Features, the DataTypes and if there are missing values in each Feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               1826 non-null   object
#  1   AVAX-USD_ADJCLOSE  583 non-null    float64
#  2   AVAX-USD_CLOSE     583 non-null    float64
#  3   AVAX-USD_HIGH      583 non-null    float64
#  4   AVAX-USD_LOW       583 non-null    float64
#  5   AVAX-USD_OPEN      583 non-null    float64
#  6   AVAX-USD_VOLUME    583 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 100.0+ KB

# %% [markdown]
# ### Missing Values

# %%
# Count the number of missing values for each Feature
df.isna().sum().to_frame().rename(columns={0: 'Count Missing Values'})
# Out:
#                    Count Missing Values
# Date                                  0
# AVAX-USD_ADJCLOSE                  1243
# AVAX-USD_CLOSE                     1243
# AVAX-USD_HIGH                      1243
# AVAX-USD_LOW                       1243
# AVAX-USD_OPEN                      1243
# AVAX-USD_VOLUME                    1243

# %% [markdown]
# ### Descriptive Statistics

# %%
# Descriptive Statistics Table
df.describe().T
# Out:
#                    count          mean           std          min  \
# AVAX-USD_ADJCLOSE  583.0  4.306912e+01  3.520897e+01     2.906161
# AVAX-USD_CLOSE     583.0  4.306912e+01  3.520897e+01     2.906161
# AVAX-USD_HIGH      583.0  4.550467e+01  3.691926e+01     2.939915
# AVAX-USD_LOW       583.0  4.066852e+01  3.358998e+01     2.788822
# AVAX-USD_OPEN      583.0  4.294390e+01  3.520388e+01     2.905293
# AVAX-USD_VOLUME    583.0  6.225375e+08  6.693453e+08  3957.000000
#
#                             25%           50%           75%           max
# AVAX-USD_ADJCLOSE  1.182176e+01  3.189084e+01  7.417818e+01  1.345310e+02
# AVAX-USD_CLOSE     1.182176e+01  3.189084e+01  7.417818e+01  1.345310e+02
# AVAX-USD_HIGH      1.243437e+01  3.469755e+01  7.804176e+01  1.462179e+02
# AVAX-USD_LOW       1.111544e+01  2.999939e+01  7.174134e+01  1.261926e+02
# AVAX-USD_OPEN      1.179604e+01  3.179400e+01  7.414628e+01  1.348656e+02
# AVAX-USD_VOLUME    7.044088e+07  3.689774e+08  1.009783e+09  3.379296e+09

# %%
# settings to display all columns
pd.set_option("display.max_columns", None)

# display the dataframe head
df.sample(n=10)
# Out:
#             Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  \
# 554   2018-11-01                NaN             NaN            NaN
# 368   2018-04-29                NaN             NaN            NaN
# 147   2017-09-20                NaN             NaN            NaN
# 705   2019-04-01                NaN             NaN            NaN
# 1600  2021-09-12           59.25943        59.25943      64.873032
# 97    2017-08-01                NaN             NaN            NaN
# 1192  2020-07-31                NaN             NaN            NaN
# 777   2019-06-12                NaN             NaN            NaN
# 211   2017-11-23                NaN             NaN            NaN
# 1094  2020-04-24                NaN             NaN            NaN
#
#       AVAX-USD_LOW  AVAX-USD_OPEN  AVAX-USD_VOLUME
# 554            NaN            NaN              NaN
# 368            NaN            NaN              NaN
# 147            NaN            NaN              NaN
# 705            NaN            NaN              NaN
# 1600     53.831429      57.098942     2.713468e+09
# 97             NaN            NaN              NaN
# 1192           NaN            NaN              NaN
# 777            NaN            NaN              NaN
# 211            NaN            NaN              NaN
# 1094           NaN            NaN              NaN

# %%
#CHECK ROWS THAT HAVE ANY MISSING VALUE IN ONE OF THE COLUMNS
is_NaN = df.isnull()
row_has_NaN = is_NaN.any(axis=1)
rows_with_NaN = df[row_has_NaN]
rows_with_NaN
# Out:
#             Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  \
# 0     2017-04-26                NaN             NaN            NaN
# 1     2017-04-27                NaN             NaN            NaN
# 2     2017-04-28                NaN             NaN            NaN
# 3     2017-04-29                NaN             NaN            NaN
# 4     2017-04-30                NaN             NaN            NaN
# ...          ...                ...             ...            ...
# 1240  2020-09-17                NaN             NaN            NaN
# 1241  2020-09-18                NaN             NaN            NaN
# 1242  2020-09-19                NaN             NaN            NaN
# 1243  2020-09-20                NaN             NaN            NaN
# 1244  2020-09-21                NaN             NaN            NaN
#
#       AVAX-USD_LOW  AVAX-USD_OPEN  AVAX-USD_VOLUME
# 0              NaN            NaN              NaN
# 1              NaN            NaN              NaN
# 2              NaN            NaN              NaN
# 3              NaN            NaN              NaN
# 4              NaN            NaN              NaN
# ...            ...            ...              ...
# 1240           NaN            NaN              NaN
# 1241           NaN            NaN              NaN
# 1242           NaN            NaN              NaN
# 1243           NaN            NaN              NaN
# 1244           NaN            NaN              NaN
#
# [1243 rows x 7 columns]

# %%
#FILTER OUT ROWS THAT ARE MISSING INFORMATION
df = df[~row_has_NaN]
df.reset_index(inplace=True, drop=True)
df
# Out:
#            Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  \
# 0    2020-07-13           4.896294        4.896294       4.915115
# 1    2020-07-14           4.986754        4.986754       5.229564
# 2    2020-09-22           5.234632        5.234632      11.463443
# 3    2020-09-23           4.118469        4.118469       5.329310
# 4    2020-09-24           4.566561        4.566561       4.751878
# ..          ...                ...             ...            ...
# 578  2022-04-21          75.080742       75.080742      80.008301
# 579  2022-04-22          74.122963       74.122963      77.152420
# 580  2022-04-23          72.920013       72.920013      74.369293
# 581  2022-04-24          71.603035       71.603035      73.437004
# 582  2022-04-25          72.867424       72.867424      72.904549
#
#      AVAX-USD_LOW  AVAX-USD_OPEN  AVAX-USD_VOLUME
# 0        4.481499       4.613968          28340.0
# 1        4.762068       4.909865           3957.0
# 2        4.125380       4.986754      288098840.0
# 3        3.982604       5.321654      173091214.0
# 4        3.539887       3.817925       96110964.0
# ..            ...            ...              ...
# 578     74.412254      78.268646      569385150.0
# 579     73.490158      75.084648      532238762.0
# 580     72.632584      74.127480      360787956.0
# 581     71.342026      72.892731      320340266.0
# 582     67.563889      71.606567      735322462.0
#
# [583 rows x 7 columns]

# %% [markdown]
# # Data Preparation
#
#
# ## <font color='#5D6D7E'>Data Transformation</font> <a class="anchor" id="eighth-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
#  __`Duplicates`__

# %%
# Checking if exist duplicated observations
print(f'\033[1m' + "Number of duplicates: " + '\033[0m', df.duplicated().sum())
# Out:
# Number of duplicates:  0

# %% [markdown]
#  __`Convert Date to correct format`__

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df
# Out:
#           Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  \
# 0   2020-07-13           4.896294        4.896294       4.915115
# 1   2020-07-14           4.986754        4.986754       5.229564
# 2   2020-09-22           5.234632        5.234632      11.463443
# 3   2020-09-23           4.118469        4.118469       5.329310
# 4   2020-09-24           4.566561        4.566561       4.751878
# ..         ...                ...             ...            ...
# 578 2022-04-21          75.080742       75.080742      80.008301
# 579 2022-04-22          74.122963       74.122963      77.152420
# 580 2022-04-23          72.920013       72.920013      74.369293
# 581 2022-04-24          71.603035       71.603035      73.437004
# 582 2022-04-25          72.867424       72.867424      72.904549
#
#      AVAX-USD_LOW  AVAX-USD_OPEN  AVAX-USD_VOLUME
# 0        4.481499       4.613968          28340.0
# 1        4.762068       4.909865           3957.0
# 2        4.125380       4.986754      288098840.0
# 3        3.982604       5.321654      173091214.0
# 4        3.539887       3.817925       96110964.0
# ..            ...            ...              ...
# 578     74.412254      78.268646      569385150.0
# 579     73.490158      75.084648      532238762.0
# 580     72.632584      74.127480      360787956.0
# 581     71.342026      72.892731      320340266.0
# 582     67.563889      71.606567      735322462.0
#
# [583 rows x 7 columns]

# %% [markdown]
#  __`Get percentual difference between open and close values and low and high values`__

# %%
df['pctDiff_CloseOpen'] = abs((df[df.columns[2]]-df[df.columns[5]])/df[df.columns[2]])*100
df['pctDiff_HighLow'] = abs((df[df.columns[3]]-df[df.columns[4]])/df[df.columns[4]])*100
df.head()
# Out:
#         Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  AVAX-USD_LOW  \
# 0 2020-07-13           4.896294        4.896294       4.915115      4.481499
# 1 2020-07-14           4.986754        4.986754       5.229564      4.762068
# 2 2020-09-22           5.234632        5.234632      11.463443      4.125380
# 3 2020-09-23           4.118469        4.118469       5.329310      3.982604
# 4 2020-09-24           4.566561        4.566561       4.751878      3.539887
#
#    AVAX-USD_OPEN  AVAX-USD_VOLUME  pctDiff_CloseOpen  pctDiff_HighLow
# 0       4.613968          28340.0           5.766121         9.675684
# 1       4.909865           3957.0           1.541865         9.817088
# 2       4.986754      288098840.0           4.735349       177.876043
# 3       5.321654      173091214.0          29.214364        33.814708
# 4       3.817925       96110964.0          16.393873        34.238123

# %%
def plot_coinValue(df):
    
    #Get coin name
    coin_name = df.columns[2].split('-')[0]
    
    #Get date and coin value
    x = df['Date']
    y = df[df.columns[2]] # ADA-USD_CLOSE
    
    #Get the volume of trades
    v = df[df.columns[-3]]/1e9
    
    #Get percentual diferences
    y2 = df[df.columns[-1]] # pctDiff_HighLow
    y1= df[df.columns[-2]]  # pctDiff_CloseOpen
    
    fig, axs = plt.subplots(3, 1, figsize=(12,14))
    
    axs[0].plot(x, y)
    axs[2].plot(x, v)
    
    # plotting the line 1 points 
    axs[1].plot(x, y1, label = "Close/Open")

    # plotting the line 2 points 
    axs[1].plot(x, y2, label = "High/Low")
    axs[1].legend()
    
    axs[0].title.set_text('Time Evolution of '+ coin_name)
    axs[0].set(xlabel="", ylabel="Close Value in USD$")
    
    axs[2].title.set_text('Volume of trades of '+ coin_name)
    axs[2].set(xlabel="", ylabel="Total number of trades in billions")
    
    
    axs[1].title.set_text('Daily Market percentual differences of '+ coin_name)
    axs[1].set(xlabel="", ylabel="Percentage (%)")
    
    plt.savefig('../analysis/'+coin_name +'_stats'+'.png')
    
    return coin_name

# %%
coin_name = plot_coinValue(df)

# %%
#FILTER DATASET
df = df.loc[df['Date']>= '2021-09-01']
df
# Out:
#           Date  AVAX-USD_ADJCLOSE  AVAX-USD_CLOSE  AVAX-USD_HIGH  \
# 346 2021-09-01          41.931602       41.931602      45.529957
# 347 2021-09-02          47.755917       47.755917      47.849262
# 348 2021-09-03          45.911182       45.911182      51.549908
# 349 2021-09-04          47.143166       47.143166      49.788338
# 350 2021-09-05          48.178925       48.178925      49.384651
# ..         ...                ...             ...            ...
# 578 2022-04-21          75.080742       75.080742      80.008301
# 579 2022-04-22          74.122963       74.122963      77.152420
# 580 2022-04-23          72.920013       72.920013      74.369293
# 581 2022-04-24          71.603035       71.603035      73.437004
# 582 2022-04-25          72.867424       72.867424      72.904549
#
#      AVAX-USD_LOW  AVAX-USD_OPEN  AVAX-USD_VOLUME  pctDiff_CloseOpen  \
# 346     38.628056      39.543476     1.042269e+09           5.695290
# 347     41.296352      42.478481     9.674747e+08          11.050851
# 348     44.889061      47.650715     1.292097e+09           3.788908
# 349     44.165131      45.900158     9.207580e+08           2.636666
# 350     45.589752      47.204662     8.703121e+08           2.022175
# ..            ...            ...              ...                ...
# 578     74.412254      78.268646     5.693852e+08           4.245968
# 579     73.490158      75.084648     5.322388e+08           1.297419
# 580     72.632584      74.127480     3.607880e+08           1.655878
# 581     71.342026      72.892731     3.203403e+08           1.801175
# 582     67.563889      71.606567     7.353225e+08           1.730343
#
#      pctDiff_HighLow
# 346        17.867587
# 347        15.868011
# 348        14.838463
# 349        12.732232
# 350         8.324018
# ..               ...
# 578         7.520329
# 579         4.983337
# 580         2.391089
# 581         2.936528
# 582         7.904607
#
# [237 rows x 9 columns]

# %% [markdown]
# # Modelling
#
#
# ## <font color='#5D6D7E'>Building LSTM Model</font> <a class="anchor" id="twentysecond-bullet"></a>
#   [Back to TOC](#toc)

# %% [markdown]
# ## Strategy
#
# Create a DF (windowed_df) where the middle columns will correspond to the close values of X days before the target date and the final column will correspond to the close value of the target date. Use these values for prediction and play with the value of X

# %%
def get_windowed_df(X, df):
    start_Date = df['Date'] + pd.Timedelta(days=X)
    
    perm = np.zeros((1,X+1))
    
    #Get labels for DataFrame
    j=1
    labels=[]
    
    while j <= X:
        label = 'closeValue_' + str(j) + 'daysBefore'
        labels.append(label)
        
        j+=1
 
    labels.append('closeValue')
    
    for i in range(X,df.shape[0]):
        temp = np.zeros((1,X+1))
        
        #Date for i-th day
        #temp[0,0] = df.iloc[i]['Date']
        
        #Close values for k days before
        for k in range(X):           
            temp[0,k] = df.iloc[i-k-1,2]
            
        #Close value for i-th date
        temp[0,-1] = df.iloc[i,2]
        

        #Add values to the permanent frame
        perm = np.vstack((perm,temp))
        
        #Get the array in dataframe form
        windowed_df = pd.DataFrame(perm[1:,:], columns = labels)
        
    return windowed_df

# %%
#Get the dataframe and append the dates
windowed_df = get_windowed_df(15, df)
windowed_df['Date'] = df.iloc[15:]['Date'].reset_index(drop=True)
windowed_df
# Out:
#      closeValue_1daysBefore  closeValue_2daysBefore  closeValue_3daysBefore  \
# 0                 57.625393               51.578117               53.110153
# 1                 67.842697               57.625393               51.578117
# 2                 69.934013               67.842697               57.625393
# 3                 69.012383               69.934013               67.842697
# 4                 70.075722               69.012383               69.934013
# ..                      ...                     ...                     ...
# 217               78.274330               80.285919               77.793678
# 218               75.080742               78.274330               80.285919
# 219               74.122963               75.080742               78.274330
# 220               72.920013               74.122963               75.080742
# 221               71.603035               72.920013               74.122963
#
#      closeValue_4daysBefore  closeValue_5daysBefore  closeValue_6daysBefore  \
# 0                 59.259430               57.164246               49.189137
# 1                 53.110153               59.259430               57.164246
# 2                 51.578117               53.110153               59.259430
# 3                 57.625393               51.578117               53.110153
# 4                 67.842697               57.625393               51.578117
# ..                      ...                     ...                     ...
# 217               75.709259               77.890266               77.437538
# 218               77.793678               75.709259               77.890266
# 219               80.285919               77.793678               75.709259
# 220               78.274330               80.285919               77.793678
# 221               75.080742               78.274330               80.285919
#
#      closeValue_7daysBefore  closeValue_8daysBefore  closeValue_9daysBefore  \
# 0                 40.772614               37.051407               37.598949
# 1                 49.189137               40.772614               37.051407
# 2                 57.164246               49.189137               40.772614
# 3                 59.259430               57.164246               49.189137
# 4                 53.110153               59.259430               57.164246
# ..                      ...                     ...                     ...
# 217               76.817856               80.001976               76.360062
# 218               77.437538               76.817856               80.001976
# 219               77.890266               77.437538               76.817856
# 220               75.709259               77.890266               77.437538
# 221               77.793678               75.709259               77.890266
#
#      closeValue_10daysBefore  closeValue_11daysBefore  \
# 0                  47.042988                48.178925
# 1                  37.598949                47.042988
# 2                  37.051407                37.598949
# 3                  40.772614                37.051407
# 4                  49.189137                40.772614
# ..                       ...                      ...
# 217                74.172615                81.816467
# 218                76.360062                74.172615
# 219                80.001976                76.360062
# 220                76.817856                80.001976
# 221                77.437538                76.817856
#
#      closeValue_12daysBefore  closeValue_13daysBefore  \
# 0                  47.143166                45.911182
# 1                  48.178925                47.143166
# 2                  47.042988                48.178925
# 3                  37.598949                47.042988
# 4                  37.051407                37.598949
# ..                       ...                      ...
# 217                84.594627                83.769226
# 218                81.816467                84.594627
# 219                74.172615                81.816467
# 220                76.360062                74.172615
# 221                80.001976                76.360062
#
#      closeValue_14daysBefore  closeValue_15daysBefore  closeValue       Date
# 0                  47.755917                41.931602   67.842697 2021-09-16
# 1                  45.911182                47.755917   69.934013 2021-09-17
# 2                  47.143166                45.911182   69.012383 2021-09-18
# 3                  48.178925                47.143166   70.075722 2021-09-19
# 4                  47.042988                48.178925   56.677929 2021-09-20
# ..                       ...                      ...         ...        ...
# 217                87.919708                82.955910   75.080742 2022-04-21
# 218                83.769226                87.919708   74.122963 2022-04-22
# 219                84.594627                83.769226   72.920013 2022-04-23
# 220                81.816467                84.594627   71.603035 2022-04-24
# 221                74.172615                81.816467   72.867424 2022-04-25
#
# [222 rows x 17 columns]

# %%
#Get the X,y and dates into a numpy array to apply on a model

def windowed_df_to_date_X_y(windowed_dataframe):
    df_as_np = windowed_dataframe.to_numpy()

    dates = df_as_np[:, -1]

    middle_matrix = df_as_np[:, 0:-2]
    X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

    Y = df_as_np[:, -2]

    return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((222,), (222, 15, 1), (222,))

# %%
#Partition for train, validation and test

q_80 = int(len(dates) * .85)
q_90 = int(len(dates) * .95)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

fig,axs = plt.subplots(1, 1, figsize=(12,5))

#Plot the partitions
axs.plot(dates_train, y_train)
axs.plot(dates_val, y_val)
axs.plot(dates_test, y_test)

axs.legend(['Train', 'Validation', 'Test'])

fig.savefig('../analysis/'+coin_name +'_partition'+'.png')

# %% [markdown]
# ## <font color='#5D6D7E'>Get Best Parameters for LSTM</font> <a class="anchor" id="twentythird-bullet"></a>
#   [Back to TOC](#toc)

# %%
#!pip install tensorflow

# %%
#import os
#os.environ['PYTHONHASHSEED']= '0'
#import numpy as np
#np.random.seed(1)
#import random as rn
#rn.seed(1)
#import tensorflow as tf
#tf.random.set_seed(1)
#
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.optimizers import Adam
#from tensorflow.keras import layers
#from sklearn.metrics import mean_squared_error
#
## Function to create LSTM model and compute the MSE value for the given parameters
#def check_model(X_train, y_train, X_val, y_val, X_test, y_test, learning_rate,epoch,batch):
#    
#    # create model
#    model = Sequential([layers.Input((15, 1)),
#                        layers.LSTM(64),
#                        layers.Dense(32, activation='relu'),
#                        layers.Dense(32, activation='relu'),
#                        layers.Dense(1)])
#    # Compile model
#    model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate), metrics=['mean_absolute_error'])
#    
#    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epoch, shuffle=False, batch_size=batch, verbose=2)
#    
#    test_predictions = model.predict(X_test).flatten()
#    
#    LSTM_mse = mean_squared_error(y_test, test_predictions)
#    
#    return LSTM_mse
#
##Function that iterates the different parameters and gets the ones corresponding to the lowest MSE score.
#def search_parameters(batch_size, epochs, learn_rate, X_train, y_train, X_val, y_val, X_test, y_test):
#    
#    best_score = float('inf')
#    
#    for b in batch_size:
#        for e in epochs:
#            for l in learn_rate:
#                print('Batch Size: ' + str(b))
#                print('Number of Epochs: ' + str(e))
#                print('Value of Learning Rate: ' + str(l))
#                try:
#                    mse = check_model(X_train, y_train, X_val, y_val, X_test, y_test,l,e,b)
#                    print('MSE=%.3f' % (mse))
#                    if mse < best_score:
#                        best_score = mse
#                        top_params = [b, e, l]
#                except:
#                    continue
#                    
#    print('Best MSE=%.3f' % (best_score))
#    print('Optimal Batch Size: ' + str(top_params[0]))
#    print('Optimal Number of Epochs: ' + str(top_params[1]))
#    print('Optimal Value of Learning Rate: ' + str(top_params[2]))
#                        
#
## define parameters
#batch_size = [10, 100, 1000]
#epochs = [50, 100]
#learn_rate = np.linspace(0.001,0.1, num=10)
#
#warnings.filterwarnings("ignore")
#search_parameters(batch_size, epochs, learn_rate, X_train, y_train, X_val, y_val, X_test, y_test)

# %% [markdown]
# ## <font color='#5D6D7E'>Run the LSTM Model and Get Predictions</font> <a class="anchor" id="twentyfourth-bullet"></a>
#   [Back to TOC](#toc)

# %%
#BEST SOLUTION OF THE MODEL

# MSE=48.801
# Batch Size: 10
# Number of Epochs: 100
# Value of Learning Rate: 0.012
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error

model = Sequential([layers.Input((15, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', 
              optimizer=Adam(learning_rate=0.012),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, shuffle=False, batch_size=10, verbose=2)
# Out:
# Epoch 1/100
# 19/19 - 2s - loss: 3509.8391 - mean_absolute_error: 51.0771 - val_loss: 413.5861 - val_mean_absolute_error: 19.2092 - 2s/epoch - 79ms/step
# Epoch 2/100
# 19/19 - 0s - loss: 844.3889 - mean_absolute_error: 24.1493 - val_loss: 46.5760 - val_mean_absolute_error: 5.7281 - 88ms/epoch - 5ms/step
# Epoch 3/100
# 19/19 - 0s - loss: 583.4008 - mean_absolute_error: 20.8197 - val_loss: 51.1840 - val_mean_absolute_error: 5.9936 - 87ms/epoch - 5ms/step
# Epoch 4/100
# 19/19 - 0s - loss: 698.2831 - mean_absolute_error: 22.3277 - val_loss: 69.4580 - val_mean_absolute_error: 6.8565 - 87ms/epoch - 5ms/step
# Epoch 5/100
# 19/19 - 0s - loss: 667.6418 - mean_absolute_error: 22.0401 - val_loss: 58.6238 - val_mean_absolute_error: 6.3881 - 87ms/epoch - 5ms/step
# Epoch 6/100
# 19/19 - 0s - loss: 664.3658 - mean_absolute_error: 22.2004 - val_loss: 48.8819 - val_mean_absolute_error: 5.8339 - 88ms/epoch - 5ms/step
# Epoch 7/100
# 19/19 - 0s - loss: 684.1302 - mean_absolute_error: 22.0995 - val_loss: 74.5210 - val_mean_absolute_error: 7.0791 - 87ms/epoch - 5ms/step
# Epoch 8/100
# 19/19 - 0s - loss: 680.8080 - mean_absolute_error: 22.2007 - val_loss: 59.2375 - val_mean_absolute_error: 6.4178 - 87ms/epoch - 5ms/step
# Epoch 9/100
# 19/19 - 0s - loss: 651.6295 - mean_absolute_error: 21.8117 - val_loss: 58.5141 - val_mean_absolute_error: 6.3826 - 87ms/epoch - 5ms/step
# Epoch 10/100
# 19/19 - 0s - loss: 686.7719 - mean_absolute_error: 22.2601 - val_loss: 66.7541 - val_mean_absolute_error: 6.7400 - 87ms/epoch - 5ms/step
# Epoch 11/100
# 19/19 - 0s - loss: 659.3005 - mean_absolute_error: 21.9110 - val_loss: 57.6813 - val_mean_absolute_error: 6.3411 - 88ms/epoch - 5ms/step
# Epoch 12/100
# 19/19 - 0s - loss: 648.9877 - mean_absolute_error: 21.7174 - val_loss: 57.3951 - val_mean_absolute_error: 6.2821 - 87ms/epoch - 5ms/step
# Epoch 13/100
# 19/19 - 0s - loss: 691.6716 - mean_absolute_error: 22.4004 - val_loss: 75.2811 - val_mean_absolute_error: 7.1109 - 87ms/epoch - 5ms/step
# Epoch 14/100
# 19/19 - 0s - loss: 687.8768 - mean_absolute_error: 22.2176 - val_loss: 58.9119 - val_mean_absolute_error: 6.3847 - 88ms/epoch - 5ms/step
# Epoch 15/100
# 19/19 - 0s - loss: 636.3349 - mean_absolute_error: 21.6540 - val_loss: 60.8302 - val_mean_absolute_error: 6.4917 - 88ms/epoch - 5ms/step
# Epoch 16/100
# 19/19 - 0s - loss: 729.3343 - mean_absolute_error: 22.9596 - val_loss: 76.0714 - val_mean_absolute_error: 7.1353 - 89ms/epoch - 5ms/step
# Epoch 17/100
# 19/19 - 0s - loss: 677.3591 - mean_absolute_error: 22.0851 - val_loss: 63.4430 - val_mean_absolute_error: 6.6061 - 89ms/epoch - 5ms/step
# Epoch 18/100
# 19/19 - 0s - loss: 661.5028 - mean_absolute_error: 21.8738 - val_loss: 60.6300 - val_mean_absolute_error: 6.4824 - 87ms/epoch - 5ms/step
# Epoch 19/100
# 19/19 - 0s - loss: 647.1346 - mean_absolute_error: 21.6417 - val_loss: 61.4662 - val_mean_absolute_error: 6.5206 - 86ms/epoch - 5ms/step
# Epoch 20/100
# 19/19 - 0s - loss: 670.1132 - mean_absolute_error: 21.9492 - val_loss: 59.8157 - val_mean_absolute_error: 6.4289 - 90ms/epoch - 5ms/step
# Epoch 21/100
# 19/19 - 0s - loss: 643.4563 - mean_absolute_error: 21.6987 - val_loss: 60.0694 - val_mean_absolute_error: 6.4558 - 88ms/epoch - 5ms/step
# Epoch 22/100
# 19/19 - 0s - loss: 668.3773 - mean_absolute_error: 21.8755 - val_loss: 64.7868 - val_mean_absolute_error: 6.6605 - 86ms/epoch - 5ms/step
# Epoch 23/100
# 19/19 - 0s - loss: 628.2687 - mean_absolute_error: 21.3843 - val_loss: 53.8301 - val_mean_absolute_error: 6.1180 - 86ms/epoch - 5ms/step
# Epoch 24/100
# 19/19 - 0s - loss: 664.9911 - mean_absolute_error: 21.9070 - val_loss: 72.4190 - val_mean_absolute_error: 6.9841 - 87ms/epoch - 5ms/step
# Epoch 25/100
# 19/19 - 0s - loss: 753.2937 - mean_absolute_error: 22.7428 - val_loss: 83.2935 - val_mean_absolute_error: 7.4060 - 88ms/epoch - 5ms/step
# Epoch 26/100
# 19/19 - 0s - loss: 631.8187 - mean_absolute_error: 21.3412 - val_loss: 58.3246 - val_mean_absolute_error: 6.3726 - 86ms/epoch - 5ms/step
# Epoch 27/100
# 19/19 - 0s - loss: 699.4987 - mean_absolute_error: 22.8046 - val_loss: 51.9545 - val_mean_absolute_error: 6.0193 - 88ms/epoch - 5ms/step
# Epoch 28/100
# 19/19 - 0s - loss: 725.8768 - mean_absolute_error: 22.0991 - val_loss: 101.1184 - val_mean_absolute_error: 8.0150 - 89ms/epoch - 5ms/step
# Epoch 29/100
# 19/19 - 0s - loss: 704.1035 - mean_absolute_error: 22.3194 - val_loss: 55.6309 - val_mean_absolute_error: 6.2308 - 89ms/epoch - 5ms/step
# Epoch 30/100
# 19/19 - 0s - loss: 645.9705 - mean_absolute_error: 21.4636 - val_loss: 88.1752 - val_mean_absolute_error: 7.8586 - 86ms/epoch - 5ms/step
# Epoch 31/100
# 19/19 - 0s - loss: 797.8964 - mean_absolute_error: 23.7889 - val_loss: 98.4118 - val_mean_absolute_error: 7.9286 - 85ms/epoch - 4ms/step
# Epoch 32/100
# 19/19 - 0s - loss: 776.1656 - mean_absolute_error: 22.5066 - val_loss: 51.5379 - val_mean_absolute_error: 6.0084 - 86ms/epoch - 5ms/step
# Epoch 33/100
# 19/19 - 0s - loss: 606.2349 - mean_absolute_error: 21.0995 - val_loss: 65.4255 - val_mean_absolute_error: 6.6876 - 86ms/epoch - 5ms/step
# Epoch 34/100
# 19/19 - 0s - loss: 671.6105 - mean_absolute_error: 21.9450 - val_loss: 63.9279 - val_mean_absolute_error: 6.6250 - 89ms/epoch - 5ms/step
# Epoch 35/100
# 19/19 - 0s - loss: 742.2783 - mean_absolute_error: 23.2860 - val_loss: 88.1021 - val_mean_absolute_error: 7.5925 - 88ms/epoch - 5ms/step
# Epoch 36/100
# 19/19 - 0s - loss: 708.2612 - mean_absolute_error: 22.1868 - val_loss: 56.4833 - val_mean_absolute_error: 6.3698 - 87ms/epoch - 5ms/step
# Epoch 37/100
# 19/19 - 0s - loss: 635.2640 - mean_absolute_error: 21.3000 - val_loss: 80.8891 - val_mean_absolute_error: 7.3320 - 85ms/epoch - 4ms/step
# Epoch 38/100
# 19/19 - 0s - loss: 658.7972 - mean_absolute_error: 21.4581 - val_loss: 52.5020 - val_mean_absolute_error: 6.0899 - 87ms/epoch - 5ms/step
# Epoch 39/100
# 19/19 - 0s - loss: 615.3955 - mean_absolute_error: 20.8818 - val_loss: 70.9323 - val_mean_absolute_error: 6.8980 - 87ms/epoch - 5ms/step
# Epoch 40/100
# 19/19 - 0s - loss: 586.1581 - mean_absolute_error: 20.4290 - val_loss: 47.4193 - val_mean_absolute_error: 5.7601 - 87ms/epoch - 5ms/step
# Epoch 41/100
# 19/19 - 0s - loss: 573.3301 - mean_absolute_error: 20.0329 - val_loss: 53.9778 - val_mean_absolute_error: 6.1373 - 86ms/epoch - 5ms/step
# Epoch 42/100
# 19/19 - 0s - loss: 537.0342 - mean_absolute_error: 19.4204 - val_loss: 51.6725 - val_mean_absolute_error: 6.1177 - 88ms/epoch - 5ms/step
# Epoch 43/100
# 19/19 - 0s - loss: 531.8354 - mean_absolute_error: 18.9086 - val_loss: 57.8308 - val_mean_absolute_error: 6.2409 - 86ms/epoch - 5ms/step
# Epoch 44/100
# 19/19 - 0s - loss: 564.5676 - mean_absolute_error: 19.4192 - val_loss: 68.6560 - val_mean_absolute_error: 6.8100 - 87ms/epoch - 5ms/step
# Epoch 45/100
# 19/19 - 0s - loss: 535.1701 - mean_absolute_error: 19.2454 - val_loss: 52.8248 - val_mean_absolute_error: 6.1907 - 89ms/epoch - 5ms/step
# Epoch 46/100
# 19/19 - 0s - loss: 499.9701 - mean_absolute_error: 18.0964 - val_loss: 45.9335 - val_mean_absolute_error: 5.7347 - 86ms/epoch - 5ms/step
# Epoch 47/100
# 19/19 - 0s - loss: 515.1816 - mean_absolute_error: 18.9378 - val_loss: 53.9453 - val_mean_absolute_error: 6.1771 - 87ms/epoch - 5ms/step
# Epoch 48/100
# 19/19 - 0s - loss: 494.0097 - mean_absolute_error: 18.6519 - val_loss: 49.3332 - val_mean_absolute_error: 5.8801 - 86ms/epoch - 5ms/step
# Epoch 49/100
# 19/19 - 0s - loss: 536.0875 - mean_absolute_error: 19.3371 - val_loss: 49.8112 - val_mean_absolute_error: 5.8919 - 85ms/epoch - 4ms/step
# Epoch 50/100
# 19/19 - 0s - loss: 493.3246 - mean_absolute_error: 18.5525 - val_loss: 59.7601 - val_mean_absolute_error: 6.4121 - 84ms/epoch - 4ms/step
# Epoch 51/100
# 19/19 - 0s - loss: 472.0993 - mean_absolute_error: 18.2044 - val_loss: 49.3197 - val_mean_absolute_error: 5.8763 - 87ms/epoch - 5ms/step
# Epoch 52/100
# 19/19 - 0s - loss: 516.7631 - mean_absolute_error: 18.8581 - val_loss: 48.3665 - val_mean_absolute_error: 5.8950 - 88ms/epoch - 5ms/step
# Epoch 53/100
# 19/19 - 0s - loss: 466.7481 - mean_absolute_error: 18.0068 - val_loss: 68.6462 - val_mean_absolute_error: 6.9668 - 88ms/epoch - 5ms/step
# Epoch 54/100
# 19/19 - 0s - loss: 487.4315 - mean_absolute_error: 18.3857 - val_loss: 56.0010 - val_mean_absolute_error: 6.2415 - 85ms/epoch - 4ms/step
# Epoch 55/100
# 19/19 - 0s - loss: 545.2690 - mean_absolute_error: 19.3757 - val_loss: 51.5620 - val_mean_absolute_error: 6.0233 - 85ms/epoch - 4ms/step
# Epoch 56/100
# 19/19 - 0s - loss: 471.4922 - mean_absolute_error: 18.1254 - val_loss: 66.4276 - val_mean_absolute_error: 6.7965 - 86ms/epoch - 5ms/step
# Epoch 57/100
# 19/19 - 0s - loss: 470.0153 - mean_absolute_error: 18.1068 - val_loss: 51.9040 - val_mean_absolute_error: 6.0054 - 88ms/epoch - 5ms/step
# Epoch 58/100
# 19/19 - 0s - loss: 501.9111 - mean_absolute_error: 18.6419 - val_loss: 50.4478 - val_mean_absolute_error: 5.9794 - 83ms/epoch - 4ms/step
# Epoch 59/100
# 19/19 - 0s - loss: 464.6212 - mean_absolute_error: 17.9230 - val_loss: 70.7704 - val_mean_absolute_error: 7.0203 - 86ms/epoch - 5ms/step
# Epoch 60/100
# 19/19 - 0s - loss: 459.6515 - mean_absolute_error: 17.8845 - val_loss: 51.7257 - val_mean_absolute_error: 5.9945 - 85ms/epoch - 4ms/step
# Epoch 61/100
# 19/19 - 0s - loss: 498.0693 - mean_absolute_error: 18.5073 - val_loss: 49.6575 - val_mean_absolute_error: 5.9140 - 86ms/epoch - 5ms/step
# Epoch 62/100
# 19/19 - 0s - loss: 460.7970 - mean_absolute_error: 17.8348 - val_loss: 70.0106 - val_mean_absolute_error: 7.0572 - 87ms/epoch - 5ms/step
# Epoch 63/100
# 19/19 - 0s - loss: 448.2140 - mean_absolute_error: 17.6188 - val_loss: 54.1315 - val_mean_absolute_error: 6.1476 - 87ms/epoch - 5ms/step
# Epoch 64/100
# 19/19 - 0s - loss: 475.7679 - mean_absolute_error: 18.0216 - val_loss: 66.9133 - val_mean_absolute_error: 6.8702 - 87ms/epoch - 5ms/step
# Epoch 65/100
# 19/19 - 0s - loss: 413.7289 - mean_absolute_error: 16.8450 - val_loss: 67.4548 - val_mean_absolute_error: 7.0425 - 86ms/epoch - 5ms/step
# Epoch 66/100
# 19/19 - 0s - loss: 536.5322 - mean_absolute_error: 18.3372 - val_loss: 72.1704 - val_mean_absolute_error: 7.0051 - 97ms/epoch - 5ms/step
# Epoch 67/100
# 19/19 - 0s - loss: 461.7344 - mean_absolute_error: 17.6024 - val_loss: 69.5953 - val_mean_absolute_error: 6.9908 - 95ms/epoch - 5ms/step
# Epoch 68/100
# 19/19 - 0s - loss: 443.3837 - mean_absolute_error: 17.5390 - val_loss: 62.0752 - val_mean_absolute_error: 6.7017 - 100ms/epoch - 5ms/step
# Epoch 69/100
# 19/19 - 0s - loss: 446.7034 - mean_absolute_error: 17.4929 - val_loss: 69.3841 - val_mean_absolute_error: 7.0136 - 99ms/epoch - 5ms/step
# Epoch 70/100
# 19/19 - 0s - loss: 437.6326 - mean_absolute_error: 17.3648 - val_loss: 64.5424 - val_mean_absolute_error: 6.8187 - 98ms/epoch - 5ms/step
# Epoch 71/100
# 19/19 - 0s - loss: 442.6147 - mean_absolute_error: 17.3928 - val_loss: 70.4952 - val_mean_absolute_error: 7.0808 - 96ms/epoch - 5ms/step
# Epoch 72/100
# 19/19 - 0s - loss: 433.1975 - mean_absolute_error: 17.2391 - val_loss: 67.2432 - val_mean_absolute_error: 6.9402 - 95ms/epoch - 5ms/step
# Epoch 73/100
# 19/19 - 0s - loss: 437.0370 - mean_absolute_error: 17.2580 - val_loss: 71.2189 - val_mean_absolute_error: 7.1304 - 95ms/epoch - 5ms/step
# Epoch 74/100
# 19/19 - 0s - loss: 429.9858 - mean_absolute_error: 17.1265 - val_loss: 70.0809 - val_mean_absolute_error: 7.0917 - 94ms/epoch - 5ms/step
# Epoch 75/100
# 19/19 - 0s - loss: 431.1436 - mean_absolute_error: 17.1167 - val_loss: 72.1263 - val_mean_absolute_error: 7.1857 - 93ms/epoch - 5ms/step
# Epoch 76/100
# 19/19 - 0s - loss: 426.5062 - mean_absolute_error: 17.0169 - val_loss: 72.4903 - val_mean_absolute_error: 7.2092 - 86ms/epoch - 5ms/step
# Epoch 77/100
# 19/19 - 0s - loss: 424.7726 - mean_absolute_error: 16.9498 - val_loss: 73.5594 - val_mean_absolute_error: 7.2591 - 88ms/epoch - 5ms/step
# Epoch 78/100
# 19/19 - 0s - loss: 418.9239 - mean_absolute_error: 16.7903 - val_loss: 74.8970 - val_mean_absolute_error: 7.3195 - 91ms/epoch - 5ms/step
# Epoch 79/100
# 19/19 - 0s - loss: 406.8843 - mean_absolute_error: 16.3509 - val_loss: 77.9760 - val_mean_absolute_error: 7.4833 - 97ms/epoch - 5ms/step
# Epoch 80/100
# 19/19 - 0s - loss: 409.1236 - mean_absolute_error: 16.3346 - val_loss: 76.8228 - val_mean_absolute_error: 7.4085 - 94ms/epoch - 5ms/step
# Epoch 81/100
# 19/19 - 0s - loss: 410.3885 - mean_absolute_error: 16.4085 - val_loss: 78.0549 - val_mean_absolute_error: 7.4797 - 98ms/epoch - 5ms/step
# Epoch 82/100
# 19/19 - 0s - loss: 402.9132 - mean_absolute_error: 16.1902 - val_loss: 80.1365 - val_mean_absolute_error: 7.5949 - 84ms/epoch - 4ms/step
# Epoch 83/100
# 19/19 - 0s - loss: 412.5080 - mean_absolute_error: 16.4548 - val_loss: 77.2683 - val_mean_absolute_error: 7.4330 - 85ms/epoch - 4ms/step
# Epoch 84/100
# 19/19 - 0s - loss: 400.2181 - mean_absolute_error: 16.1323 - val_loss: 82.2423 - val_mean_absolute_error: 7.6942 - 83ms/epoch - 4ms/step
# Epoch 85/100
# 19/19 - 0s - loss: 411.1343 - mean_absolute_error: 16.4117 - val_loss: 77.8952 - val_mean_absolute_error: 7.4618 - 87ms/epoch - 5ms/step
# Epoch 86/100
# 19/19 - 0s - loss: 398.7917 - mean_absolute_error: 16.0954 - val_loss: 83.0719 - val_mean_absolute_error: 7.7309 - 98ms/epoch - 5ms/step
# Epoch 87/100
# 19/19 - 0s - loss: 408.4338 - mean_absolute_error: 16.3372 - val_loss: 79.7170 - val_mean_absolute_error: 7.5592 - 105ms/epoch - 6ms/step
# Epoch 88/100
# 19/19 - 0s - loss: 397.2206 - mean_absolute_error: 16.0536 - val_loss: 83.8297 - val_mean_absolute_error: 7.7634 - 104ms/epoch - 5ms/step
# Epoch 89/100
# 19/19 - 0s - loss: 406.4821 - mean_absolute_error: 16.2806 - val_loss: 81.2674 - val_mean_absolute_error: 7.6389 - 104ms/epoch - 5ms/step
# Epoch 90/100
# 19/19 - 0s - loss: 395.5998 - mean_absolute_error: 16.0133 - val_loss: 84.6922 - val_mean_absolute_error: 7.7995 - 91ms/epoch - 5ms/step
# Epoch 91/100
# 19/19 - 0s - loss: 404.6466 - mean_absolute_error: 16.2276 - val_loss: 82.6004 - val_mean_absolute_error: 7.7030 - 97ms/epoch - 5ms/step
# Epoch 92/100
# 19/19 - 0s - loss: 394.2311 - mean_absolute_error: 15.9787 - val_loss: 85.5408 - val_mean_absolute_error: 7.8338 - 100ms/epoch - 5ms/step
# Epoch 93/100
# 19/19 - 0s - loss: 402.8717 - mean_absolute_error: 16.1792 - val_loss: 83.8227 - val_mean_absolute_error: 7.7588 - 97ms/epoch - 5ms/step
# Epoch 94/100
# 19/19 - 0s - loss: 392.9984 - mean_absolute_error: 15.9474 - val_loss: 86.3720 - val_mean_absolute_error: 7.8663 - 102ms/epoch - 5ms/step
# Epoch 95/100
# 19/19 - 0s - loss: 401.2330 - mean_absolute_error: 16.1344 - val_loss: 84.9389 - val_mean_absolute_error: 7.8073 - 102ms/epoch - 5ms/step
# Epoch 96/100
# 19/19 - 0s - loss: 391.8331 - mean_absolute_error: 15.9181 - val_loss: 87.1852 - val_mean_absolute_error: 7.8970 - 98ms/epoch - 5ms/step
# Epoch 97/100
# 19/19 - 0s - loss: 399.7158 - mean_absolute_error: 16.0927 - val_loss: 85.9667 - val_mean_absolute_error: 7.8499 - 97ms/epoch - 5ms/step
# Epoch 98/100
# 19/19 - 0s - loss: 390.7178 - mean_absolute_error: 15.8899 - val_loss: 87.9744 - val_mean_absolute_error: 7.9258 - 83ms/epoch - 4ms/step
# Epoch 99/100
# 19/19 - 0s - loss: 398.2978 - mean_absolute_error: 16.0533 - val_loss: 86.9221 - val_mean_absolute_error: 7.8877 - 91ms/epoch - 5ms/step
# Epoch 100/100
# 19/19 - 0s - loss: 389.6411 - mean_absolute_error: 15.8626 - val_loss: 88.7369 - val_mean_absolute_error: 7.9568 - 84ms/epoch - 4ms/step

# %%
#PREDICT THE VALUES USING THE MODEL
train_predictions = model.predict(X_train).flatten()
val_predictions = model.predict(X_val).flatten()
test_predictions = model.predict(X_test).flatten()


fig,axs = plt.subplots(3, 1, figsize=(14,14))

axs[0].plot(dates_train, train_predictions)
axs[0].plot(dates_train, y_train)
axs[0].legend(['Training Predictions', 'Training Observations'])

axs[1].plot(dates_val, val_predictions)
axs[1].plot(dates_val, y_val)
axs[1].legend(['Validation Predictions', 'Validation Observations'])

axs[2].plot(dates_test, test_predictions)
axs[2].plot(dates_test, y_test)
axs[2].legend(['Testing Predictions', 'Testing Observations'])

plt.savefig('../analysis/LTSM_recursive/'+coin_name +'_modelPredictions'+'.png')

# %% [markdown]
# ## <font color='#5D6D7E'>Recursive Predictions</font> <a class="anchor" id="twentysixth-bullet"></a>
#   [Back to TOC](#toc)

# %%
from copy import deepcopy

#Get prediction for future dates recursively based on the previous existing information. Then update the window of days upon
#which the predictions are made

recursive_predictions = []
recursive_dates = np.concatenate([dates_test])

extra_dates = np.array(['2022-05-09', '2022-05-10', '2022-05-11'])
recursive_dates = np.append(recursive_dates,extra_dates)

last_window = deepcopy(X_train[-1])

for target_date in recursive_dates:
    next_prediction = model.predict(np.array([last_window])).flatten()
    recursive_predictions.append(next_prediction)
    last_window = np.insert(last_window,0,next_prediction)[:-1]

# %%
fig,axs = plt.subplots(2, 1, figsize=(14,10))

axs[0].plot(dates_train, train_predictions)
axs[0].plot(dates_train, y_train)
axs[0].plot(dates_val, val_predictions)
axs[0].plot(dates_val, y_val)
axs[0].plot(dates_test, test_predictions)
axs[0].plot(dates_test, y_test)
axs[0].plot(recursive_dates, recursive_predictions)
axs[0].legend(['Training Predictions', 
               'Training Observations',
               'Validation Predictions', 
               'Validation Observations',
               'Testing Predictions', 
               'Testing Observations',
               'Recursive Predictions'])

axs[1].plot(dates_test, y_test)
axs[1].plot(recursive_dates, recursive_predictions)
axs[1].legend(['Testing Observations',
              'Recursive Predictions'])

plt.savefig('../analysis/LTSM_recursive/'+ coin_name +'_recursivePredictions'+'.png')

# %%
may_10_prediction = coin_name +'-USD',recursive_predictions[-2][0]
may_10_prediction
# Out:
# ('AVAX-USD', 92.39853)
